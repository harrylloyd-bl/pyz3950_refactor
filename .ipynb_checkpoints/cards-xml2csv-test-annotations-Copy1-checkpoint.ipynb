# %%
import pandas as pd
import lxml
import glob
from lxml import etree
from bs4 import BeautifulSoup
import re 
import requests
from urllib.parse import quote
import sys
import os
import shutil
import json
from pathlib import Path

import random
import functools
from IPython.display import display, clear_output
from ipywidgets import Button, Dropdown, HTML, HBox, IntSlider, FloatSlider, Textarea, Output


ns = "{http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15}"
cards = './urdu_cards_pages/1032971/U2_for_Transkribus/page/*.xml'

# %%
cards_samples = []
for card in glob.glob(cards)[:5]:
    cards_samples.append(card)

cards_samples
# Out:
# ['./urdu_cards_pages/1032971/U2_for_Transkribus/page/0024_24567998184.xml',
#  './urdu_cards_pages/1032971/U2_for_Transkribus/page/0036_24567999964.xml',
#  './urdu_cards_pages/1032971/U2_for_Transkribus/page/0040_24568000444.xml',
#  './urdu_cards_pages/1032971/U2_for_Transkribus/page/0034_24567999574.xml',
#  './urdu_cards_pages/1032971/U2_for_Transkribus/page/0037_24568000074.xml']

# %%
metadata = pd.DataFrame()
shelfmarks = []
authors = []
titles = []
query = []
query_results = []



def searchWorldCat(results,shelfmark, author, title, url, n_pages, queryType):
    #CONSTRUCT URLS
    urls = [url]  
    if n_pages > 1:
        if n_pages > 10:
            end = 11
        else:
            end=n_pages+1
        for i in range(1,end):
            urls.append(url+'&start='+str(i*10+1)+'&qt=page_number_link')

    print('===========')
    print("CARD TRANSCRIPTION")
    print('Shelfmark = '+ shelfmark)
    print('Author = '+ author)
    print('Title = '+ title)
    print()
    print("**PARAMETERS USED ON WORLDCAT**")
    print('Query parameters: ' + queryType)
    print('N. results: ' + str(results))
    print('===========')
    print()
    print("RESULTS (limited to max 100):")

    n = 1

    for u in urls:
        page = requests.get(u)
        soup = BeautifulSoup(page.content, 'html.parser')
        results = soup.select('a[id*=result]')
        for result in results:
            s = str(result['href'])
            print(n)
            title = result.find('strong').text  
            print('Title: '+ title)
            ocloc_id = re.search(r'[0-9]{6,}', s)
            print('ocloc_id: '+ ocloc_id.group(0))
            url = 'http://www.worldcat.org/oclc/'+ocloc_id.group(0)
            print('URL: '+ url)
            print('===========')
            print()
            n +=1


for card in cards_samples:
    with open(card, "r") as file:
        results_title_surname=[]
        results_surname =[]
        n_pages =[]
        
        print(card)
        
        soup = BeautifulSoup(file, 'xml')
        shelfmark = soup.select('TextRegion[custom*=shelfmark]')[0].find_all('TextLine', recursive=False)[0].find_all('TextEquiv', recursive=False)[0].find_all('Unicode', recursive=False)[0]
        shelfmark = shelfmark.get_text()
        author = soup.select('TextRegion[custom*=author]')[0].find_all('TextLine', recursive=False)[0].find_all('TextEquiv', recursive=False)[0].find_all('Unicode', recursive=False)[0]
        author = author.get_text()
        title = soup.select('TextRegion[custom*=title]')[0].find_all('TextLine', recursive=False)[0].find_all('TextEquiv', recursive=False)[0].find_all('Unicode', recursive=False)[0]
        title = title.get_text()
        
        #SAVE METADATA
        shelfmarks.append(shelfmark)
        authors.append(author)
        titles.append(title)
        
        surname = author.split(',')[0]
        surname_encoded = quote(surname)
        title_encoded = quote(title)
        
        #sys.stdout = open(card.split('/')[-1].replace('xml', 'txt'),'wt')

        #INITIAL QUERY
        url = ['https://www.worldcat.org/search?q=ti%3A'+title_encoded+'+au%3A'+surname_encoded+'&qt=advanced&dblist=638',
               'https://www.worldcat.org/search?q=ti%3A+au%3A'+surname_encoded+'&qt=advanced&dblist=638']
        
        
        #CHECK NUMBER OF RESULTS
        page = requests.get(url[0])
        soup = BeautifulSoup(page.content, 'html.parser')
        try:
            results_title_surname = soup.select('div[class=resultsinfo]')[0].find_all('td')[0].find_all('strong')[1].get_text()
            queryType='surname-title'
            n_pages = int(float(results_title_surname.replace(',', '')))//10
            searchWorldCat(results_title_surname, shelfmark, author, title, url[0], n_pages, queryType)
        except:  
            page = requests.get(url[1])
            soup = BeautifulSoup(page.content, 'html.parser')
            try:      
                results_surname = soup.select('div[class=resultsinfo]')[0].find_all('td')[0].find_all('strong')[1].get_text()
                queryType='surname'
                n_pages = int(float(results_surname.replace(',', '')))//10
                searchWorldCat(results_surname, shelfmark, author, title, url[1], n_pages, queryType)
            except:
                queryType='surname-title/surname'
                n_pages = "NO RESULTS"
        query.append(queryType)
        query_results.append(n_pages)
# Out:
# ./urdu_cards_pages/1032971/U2_for_Transkribus/page/0024_24567998184.xml
# ===========
# CARD TRANSCRIPTION
# Shelfmark = 14117. bbb. 24.
# Author = 'ABD al-RAHMAN, Hafiz, Amritsari.
# Title = KITAB AL-SARF
#
# **PARAMETERS USED ON WORLDCAT**
# Query parameters: surname-title
# N. results: 11
# ===========
#
# RESULTS (limited to max 100):
# 1
# Title: Kitāb al- Miftāḥ fi 'ṣ-ṣarf
# ocloc_id: 165516626
# URL: http://www.worldcat.org/oclc/165516626
# ===========
#
# 2
# Title: كتاب المفتاح في الصرف /
# Kitāb al-miftāḥ fī al-ṣarf
# ocloc_id: 21939710
# URL: http://www.worldcat.org/oclc/21939710
# ===========
#
# 3
# Title: Kitāb Al-miftāḥ fī l-ṣarf
# ocloc_id: 1025689800
# URL: http://www.worldcat.org/oclc/1025689800
# ===========
#
# 4
# Title: مجموعة صرف ونحو.
# Majmūʻat ṣarf wa-naḥw.
# ocloc_id: 987285071
# URL: http://www.worldcat.org/oclc/987285071
# ===========
#
# 5
# Title: Kitab al-sarf.
# ocloc_id: 1193199448
# URL: http://www.worldcat.org/oclc/1193199448
# ===========
#
# 6
# Title: تيسير الصرف بمضمون كتاب شذا العرف في فن الصرف للأستاذ الشيخ أحمد الحملاوي /
# Taysīr al-ṣarf bi-maḍmūn kitāb Shadhā al-ʻarf fī fann al-ṣarf lil-Ustādh al-Shaykh Aḥmad al-Ḥamalāwī
# ocloc_id: 680452175
# URL: http://www.worldcat.org/oclc/680452175
# ===========
#
# 7
# Title: المفتاح فى الصرف كتاب.
# ocloc_id: 957286989
# URL: http://www.worldcat.org/oclc/957286989
# ===========
#
# 8
# Title: فتح اللطيف في التصريف على البسط و التعريف : كتاب نفيس فيه أبحاث دقيقة في فن الصرف للطلبة و المتخصصين
# ocloc_id: 957051623
# URL: http://www.worldcat.org/oclc/957051623
# ===========
#
# 9
# Title: مباهج الأعلام في مناهج الأقلام : مما ألقاه رسول الحكمة من خزائن الرحمة، و يليه كتاب سر الأسرار في استحضار الجن و صرف العماّر للشيخ محمد التونسي المغربي /
# Mabāhij al-aʿlām fī manāhij al-aqlām : mimmā alqāhu Rasūl al-ḥikmah min khazāʼin al-raḥmān, wa-yalīhi kitāb Sirr al-asrār fī istiḥḍār al-jinn wa-ṣarf al-ʿammār lil-shaykh Muḥammad al-Tūnisī al-Maghribī
# ocloc_id: 1062297099
# URL: http://www.worldcat.org/oclc/1062297099
# ===========
#
# 10
# Title: شرح ابن عقيل على ألفية ابن مالك /‏
# ocloc_id: 957269476
# URL: http://www.worldcat.org/oclc/957269476
# ===========
#
# ./urdu_cards_pages/1032971/U2_for_Transkribus/page/0036_24567999964.xml
# ===========
# CARD TRANSCRIPTION
# Shelfmark = 14105. d. 106.
# Author = 'ABD al-SHAKUR, Maulana
# Title = KHULAFA'E RASHIDIN
#
# **PARAMETERS USED ON WORLDCAT**
# Query parameters: surname
# N. results: 280
# ===========
#
# RESULTS (limited to max 100):
# 1
# Title: Palimpsests of themselves : logic and commentary in postclassical Muslim South Asia
# ocloc_id: 1289617062
# URL: http://www.worldcat.org/oclc/1289617062
# ===========
#
# 2
# Title: حسرت موہانى : سوانح حىات، تبصرہ، موازنہ و انتخاب کلام /
# Ḥasrat Mohānī : savānaḥ ḥayāt, tabṣirah, mavāznah va intik̲h̲āb-i kalām
# ocloc_id: 973889139
# URL: http://www.worldcat.org/oclc/973889139
# ===========
#
# 3
# Title: نخب تأريخية جامعة لأخبار المغرب الأوسط. الجزء الأول /
# Nukhab ta'rīkhīyah jāmi'ah li-akhbār al-maghrib al-awsaṭ. al-juz' al-awwal
# ocloc_id: 900891886
# URL: http://www.worldcat.org/oclc/900891886
# ===========
#
# 4
# Title: مجمع بحار الانوار في غرائب التنزيل ولطائف الاخبار.
# Majmaʻ biḥār al-anwār fī gharāʼib al-tanzīl wa-laṭāʼif al-akhbār.
# ocloc_id: 1085513903
# URL: http://www.worldcat.org/oclc/1085513903
# ===========
#
# 5
# Title: فواتح الرحموت بشرح مسلم الثبوت لمحب الله بن عبد الشكور البهاري /
# ocloc_id: 956922746
# URL: http://www.worldcat.org/oclc/956922746
# ===========
#
# 6
# Title: التراث الملبسي للمرأة في فلسطين /
# al-Turāth al-malbasī lil-marʼah fī Filasṭīn
# ocloc_id: 368181388
# URL: http://www.worldcat.org/oclc/368181388
# ===========
#
# 7
# Title: Muḥibb Allāh Musallam al-thubūt
# ocloc_id: 874783318
# URL: http://www.worldcat.org/oclc/874783318
# ===========
#
# 8
# Title: Adabī nas̲rūnah ; Da Benawā yād ; Da kārnāmo mermanī ; Da gulo geḍay
# ocloc_id: 213584318
# URL: http://www.worldcat.org/oclc/213584318
# ===========
#
# 9
# Title: سلم العلوم.
# Sullam al-ʻulūm
# ocloc_id: 978500335
# URL: http://www.worldcat.org/oclc/978500335
# ===========
#
# 10
# Title: داوود عبد السيد : سيرة سينمائية /
# Dāwūd ʻAbd al-Sayyid : sīrah sīnimāʼīyah
# ocloc_id: 1280302111
# URL: http://www.worldcat.org/oclc/1280302111
# ===========
#
# 11
# Title: شرح بحر العلوم /
# Sharḥ baḥr al-ʻulūm
# ocloc_id: 999863738
# URL: http://www.worldcat.org/oclc/999863738
# ===========
#
# 12
# Title: أقنعة السرد : (مقالات نقدية عن روايات مصرية وعربية وعالمية) /
# Aqniʻat al-sard : (maqālāt naqdīyah ʻan riwāyāt Miṣrīyah wa-ʻArabīyah wa-ʻālamīyah)
# ocloc_id: 1184011028
# URL: http://www.worldcat.org/oclc/1184011028
# ===========
#
# 13
# Title: المستصفى من علم الأصول \
# al-Mustaṣfá min ʻilm al-uṣūl
# ocloc_id: 174935469
# URL: http://www.worldcat.org/oclc/174935469
# ===========
#
# 14
# Title: پښتانه شعراء : بشپړ متن /
# Puṣhtānah shuʻarāʼ : bashpaṛ matn
# ocloc_id: 844075444
# URL: http://www.worldcat.org/oclc/844075444
# ===========
#
# 15
# Title: داستان پدموات /
# Dāstān-i Padmāvat
# ocloc_id: 23541931
# URL: http://www.worldcat.org/oclc/23541931
# ===========
#
# 16
# Title: شرح بحر العلوم على سلم العلوم في علم المنطق على سلم العلوم في علم المنطق للإمام الشيخ محب الله بن عبد الشكور العثماني الحنفي البيهاري الهندي، صاحب مسلم الثبوت ت 1119 /
# Sharḥ Baḥr al-ʻUlūm ʻalá Sullam al-ʻulūm fī ʻilm al-manṭiq lil-Imām al-Shaykh Muḥibb Allāh ibn ʻAbd al-Shakūr al-ʻUthmānī al-Ḥanafī al-Bayhārī al-Hindī, ṣāḥib Musallam al-thubūt t 1119 H
# ocloc_id: 983725371
# URL: http://www.worldcat.org/oclc/983725371
# ===========
#
# 17
# Title: كيف تشاهد فيلما سينمائيا؟ /
# Kayfa tushāhid fīlman sīnmāʼiyan?
# ocloc_id: 1122911366
# URL: http://www.worldcat.org/oclc/1122911366
# ===========
#
# 18
# Title: سينما مصر : زيارة جديدة لأفلام قديمة /
# Sīnimā Miṣr : ziyārah jadīdah li-aflām qadīmah
# ocloc_id: 1285958895
# URL: http://www.worldcat.org/oclc/1285958895
# ===========
#
# 19
# Title: قالت امي ... : امثال شعبية : لبنت المدينة المنورة /
# Qālat ummī ... : amthāl shaʻbīyah : li-bint al-Madīnah al-Munawwarah
# ocloc_id: 891184619
# URL: http://www.worldcat.org/oclc/891184619
# ===========
#
# 20
# Title: حبيبة : كما حكاها نديم : رواية /
# Ḥabībah : ka-mā ḥakāhā Nadīm : riwāyah
# ocloc_id: 1274126781
# URL: http://www.worldcat.org/oclc/1274126781
# ===========
#
# 21
# Title: ونس الكتب : روايات، قصص، شعر، أدب رحلات، مذكرات، سيرة ذاتية /
# Wanas al-kutub : riwāyāt, qiṣaṣ, shiʻr, adab riḥlāt, mudhakkirāt, sīrah dhātīyah
# ocloc_id: 1262334475
# URL: http://www.worldcat.org/oclc/1262334475
# ===========
#
# 22
# Title: كتاب المستصفى من علم الصول /
# Kitāb al-mustaṣfá min ʻilm al-uṣūl
# ocloc_id: 54568405
# URL: http://www.worldcat.org/oclc/54568405
# ===========
#
# 23
# Title: ‏كتاب المستصفى من علم الأصول /‏
# Kitāb al-mustaṣfá min ʻilm al-uṣūl
# ocloc_id: 891558374
# URL: http://www.worldcat.org/oclc/891558374
# ===========
#
# 24
# Title: كنت شابا في الثمانينيات : سيرة ثقافية واجتماعية /
# Kuntu shābban fī al-thamānīnīyāt : sīrah thaqāfīyah wa-ijtimāʻīyah
# ocloc_id: 1175585358
# URL: http://www.worldcat.org/oclc/1175585358
# ===========
#
# 25
# Title: المستصفى من علم الاصول /
# al-Mustaṣfá min ʻilm al-uṣūl
# ocloc_id: 643799781
# URL: http://www.worldcat.org/oclc/643799781
# ===========
#
# 26
# Title: فواتح الرحموت /
# Fawātiḥ al-raḥamūt
# ocloc_id: 990338512
# URL: http://www.worldcat.org/oclc/990338512
# ===========
#
# 27
# Title: كتاب المستصفى في علم الأصول . الجزء الثاني /
# Kitāb al-Musṭaṣfá fī ʻilm al-uṣūl . vol. 2
# ocloc_id: 711957454
# URL: http://www.worldcat.org/oclc/711957454
# ===========
#
# 28
# Title: ‏ذاكرة الظلال والمرايا :‏ ‏دراسات في أدب محمد ناجي /‏
# Dhākirat al-ẓilāl wa-al-marāyā : dirāsāt fī adab Muḥammad Nājī
# ocloc_id: 1039218359
# URL: http://www.worldcat.org/oclc/1039218359
# ===========
#
# 29
# Title: مقالاتى در پيرامون مباحث مسودۀ قانون اساسى : مجموعۀ مقالات /
# Maqālātī dar pīrāmūn-i mabāḥis̲-i musavvadah-ʼi qānūn-i asāsī : majmūʻah-ʼi maqālāt
# ocloc_id: 957464575
# URL: http://www.worldcat.org/oclc/957464575
# ===========
#
# 30
# Title: المسلم في أصول الفقه مع حاشيته، المعروف بمسلم الثبوت /
# al-Musallam fī uṣūl al-fiqh maʻa ḥāshiyatihi al-maʻrūf bi-Musallam al-thubūt
# ocloc_id: 1245493434
# URL: http://www.worldcat.org/oclc/1245493434
# ===========
#
# 31
# Title: المستصفى في علم الأصول /
# al-Mustasfá min ʻilm al-uṣūl
# ocloc_id: 886708395
# URL: http://www.worldcat.org/oclc/886708395
# ===========
#
# 32
# Title: د احمد شاه بابا کتابښود = Də Ahmad Šāh Bābā ketābşod : the bibliography of Ahmad Shah Baba /
# Da Aḥmad Shāh Bābā kitābṣhūd = Də Ahmad Šāh Bābā ketābşod : the bibliography of Ahmad Shah Baba
# ocloc_id: 1193557367
# URL: http://www.worldcat.org/oclc/1193557367
# ===========
#
# 33
# Title: Sullam al-ʻulūm
# ocloc_id: 224918060
# URL: http://www.worldcat.org/oclc/224918060
# ===========
#
# 34
# Title: گزينه مقالات خرمن خوشه‌ها /
# Guzīnah-i maqālāt kharman-i khūshahʹhā
# ocloc_id: 694183936
# URL: http://www.worldcat.org/oclc/694183936
# ===========
#
# 35
# Title: شرح سلم مولوي حمد الله /
# Sharḥ Sullam Mawlawī Ḥamd Allāh
# ocloc_id: 81628764
# URL: http://www.worldcat.org/oclc/81628764
# ===========
#
# 36
# Title: لا يليق ... : [رواية] /
# Lā yalīq ... : [riwāyah]
# ocloc_id: 854502761
# URL: http://www.worldcat.org/oclc/854502761
# ===========
#
# 37
# Title: عجالتا براى تو /
# ʻIjālatan barā-yi tū
# ocloc_id: 886667229
# URL: http://www.worldcat.org/oclc/886667229
# ===========
#
# 38
# Title: Taḥrīr-i Būstah : sharḥ-i Sullam al-ʻulūm
# ocloc_id: 31285256
# URL: http://www.worldcat.org/oclc/31285256
# ===========
#
# 39
# Title: شهيرات الأندلس /
# Shahīrāt al-Andalus
# ocloc_id: 1184007554
# URL: http://www.worldcat.org/oclc/1184007554
# ===========
#
# 40
# Title: مجموعة : 1. القاضي مع المنهيات, 2. الحاشية لمولانا محمد يوسف, 3. الحاشية لمولانا حافظ الدراز, 4. السلم مع التنبيهات.
# Majmūʻah : 1. al-Qāḍī maʻa al-manhīyāt, 2. al-Ḥāshiyah li-Mawlānā Muḥammad Yūsuf, 3. al-Ḥāshiyah li-Mawlānā Ḥāfiẓ Darrāz, 4. al-Sullam maʻa al-Tanbīhāt.
# ocloc_id: 786397212
# URL: http://www.worldcat.org/oclc/786397212
# ===========
# 41
# Title: تذكرهي شاه طهماسب : شرح وقائيع و احوالات زندگانيي شاه طهماسب صفوي بقلم خودش /
# Taz̲kirah-i Shāh Ṭahmāsb : sharḥ-i vaqāʼīʻ va aḥvālāt-i zindagānī-i Shāh Ṭahmāsb-i Ṣafavī bi-qalam-i khvudash
# ocloc_id: 652092749
# URL: http://www.worldcat.org/oclc/652092749
# ===========
#
# 42
# Title: د پښتو نظم عروضى سيستم : سيلابوتونيک = The metric system of Pashto poetry : syllabic-tonic /
# Da Puṣhto niz̤am ʻarūẓī sīstam : sīlābūtūnīk = The metric system of Pashto poetry : syllabic-tonic
# ocloc_id: 1228212947
# URL: http://www.worldcat.org/oclc/1228212947
# ===========
#
# 43
# Title: حاشية الشيخ إبراهيم البيجوري على شرح العلامة ابن القاسم الغزي على متن الشيخ أبي شجاع في مذهب الإمام الشافعي. الجزء الرابع /
# Ḥāshiyat al-Shaykh Ibrāhīm al-Bījūrī ʻalá sharḥ al-ʻAllāmah Ibn al-Qāsim al-Ghazzī ʻalá matn al-Shaykh Abī Shujāʻ fī madhhab al-Imām al-Shāfiʻī. al-Juz' al-rābiʻ
# ocloc_id: 1184009034
# URL: http://www.worldcat.org/oclc/1184009034
# ===========
#
# 44
# Title: إشارة المرام من عبارات الإمام /
# Ishārat al-marām min ʻibārāt al-Imām
# ocloc_id: 1282641587
# URL: http://www.worldcat.org/oclc/1282641587
# ===========
#
# 45
# Title: الأصول المنيفة للإمام أبي حنيفة /
# al-Uṣūl al-munīfah lil-Imām Abī Ḥanīfah
# ocloc_id: 1200507741
# URL: http://www.worldcat.org/oclc/1200507741
# ===========
#
# 46
# Title: نخب تاريخية جامعة لاخبار المغرب الاوسط /
# Nukhab tārīkhīyah jāmiʻah li-akhbār al-Maghrib al-awsaṭ
# ocloc_id: 851349265
# URL: http://www.worldcat.org/oclc/851349265
# ===========
#
# 47
# Title: المرأة في الامثال الشعبية : ما قيل عنها وما قالته /
# al-Marʼah fī al-amthāl al-shaʻbīyah : mā qīla ʻanhā wa-mā qālat'hu
# ocloc_id: 892576909
# URL: http://www.worldcat.org/oclc/892576909
# ===========
#
# 48
# Title: حضرت ابو بکر صدىق /
# Ḥaz̤rat Abū Bakr Ṣiddīq
# ocloc_id: 213465500
# URL: http://www.worldcat.org/oclc/213465500
# ===========
#
# 49
# Title: افسانۀ بيرق و سير افسانوى آن در کشور /
# Afsānah-ʼi Bayraq va sayr-i afsānavī-i ān dar kishvar
# ocloc_id: 867001447
# URL: http://www.worldcat.org/oclc/867001447
# ===========
#
# 50
# Title: جغرافيايې ياداښتونه /
# Jughrāfiyāye yādāṣhtūnah
# ocloc_id: 764598348
# URL: http://www.worldcat.org/oclc/764598348
# ===========
#
# 51
# Title: د پښتو پخوانى الفبې /
# Da Puṣhto pakhwānay Alafbe
# ocloc_id: 714329386
# URL: http://www.worldcat.org/oclc/714329386
# ===========
#
# 52
# Title: امين الملک ګل محمد خان غورياخېل بابړ او د هغه کورنى /
# Amīn al-Mulk Gul Muḥammad Khān Ghwaryākhel Bābaṛ aw da haghah koranay
# ocloc_id: 793098167
# URL: http://www.worldcat.org/oclc/793098167
# ===========
#
# 53
# Title: Makhārij al-hurūf
# ocloc_id: 30995643
# URL: http://www.worldcat.org/oclc/30995643
# ===========
#
# 54
# Title: العلل الصغير /
# al-ʻIlal al-ṣaghīr
# ocloc_id: 145579676
# URL: http://www.worldcat.org/oclc/145579676
# ===========
#
# 55
# Title: طرز العمارة الجنائزية في العالم الإسلامي : عمارة الترب المتجاورة /
# Ṭuruz al-ʻimārah al-janāʼizīyah fī al-ʻālam al-Islāmī : ʻimārat al-turab al-mutajāwirah
# ocloc_id: 1107411657
# URL: http://www.worldcat.org/oclc/1107411657
# ===========
#
# 56
# Title: دختران رودخانه‌ى هيرمند /
# Dukhtarān-i rūdkhānah-yi Hīrmand
# ocloc_id: 859254210
# URL: http://www.worldcat.org/oclc/859254210
# ===========
#
# 57
# Title: Guzīnah-i maqālāt-i kharman-i khūshahʹhā
# ocloc_id: 708745321
# URL: http://www.worldcat.org/oclc/708745321
# ===========
#
# 58
# Title: عقاب چه گونه مى‌ميرد : مجموعه شعر /
# ʻUqāb chih gūnah mīʹmīrad : majmūʻah-i shiʻr
# ocloc_id: 785552250
# URL: http://www.worldcat.org/oclc/785552250
# ===========
#
# 59
# Title: Lodī Puṣhtānạh
# ocloc_id: 34429116
# URL: http://www.worldcat.org/oclc/34429116
# ===========
#
# 60
# Title: قيام الليل ؛ و، قيام رمضان ؛ و، كتاب الوتر /
# Qiyām al-layl ; wa, Qiyām Ramaḍān ; wa, Kitāb al-witr
# ocloc_id: 20910972
# URL: http://www.worldcat.org/oclc/20910972
# ===========
#
# 61
# Title: خواب خرد : تأملاتى در باب زمان حال /
# Khvāb-i khirad : taʼmmulātī dar bāb-i zamān-i ḥāl
# ocloc_id: 857676187
# URL: http://www.worldcat.org/oclc/857676187
# ===========
#
# 62
# Title: حادثة الإفك ودلالاتها الفقهية والأصولية /
# Ḥādithat al-ifk wa-dalālātuhā al-fiqhīyah wa-al-uṣūlīyah
# ocloc_id: 911267292
# URL: http://www.worldcat.org/oclc/911267292
# ===========
#
# 63
# Title: شخصيت علمى، سياسى و اجتماعى شهيد ميوندوال /
# Shakhṣīyat-i ʻilmī, siyasī va ijtimāʻī-i shahīd Mayvandvāl
# ocloc_id: 52278134
# URL: http://www.worldcat.org/oclc/52278134
# ===========
#
# 64
# Title: ميهنم /
# Mīhanam
# ocloc_id: 49560481
# URL: http://www.worldcat.org/oclc/49560481
# ===========
#
# 65
# Title: سپاه هندوکش /
# Sipāh-i Hindūkush
# ocloc_id: 51826250
# URL: http://www.worldcat.org/oclc/51826250
# ===========
#
# 66
# Title: د دولت لواڼى ديوان /
# Da Dawlat Lawāṇay dīwān
# ocloc_id: 861073189
# URL: http://www.worldcat.org/oclc/861073189
# ===========
#
# 67
# Title: د احمد شاهى عصر نوميالى /
# Da Aḥmad Shāhī ʻaṣr nūmyālī
# ocloc_id: 1154813251
# URL: http://www.worldcat.org/oclc/1154813251
# ===========
#
# 68
# Title: الاهتمام بأمر المسلمين : مفهومه - ضوابطه - أهميته - مجالاته، دراسة دعوية /
# al-Ihtimām bi-amr al-Muslimīn : mafhūmuh - ḍawābiṭuh - ahammīyatuh - majālātuh, dirāsah daʻawīyah
# ocloc_id: 1193229315
# URL: http://www.worldcat.org/oclc/1193229315
# ===========
#
# 69
# Title: Ḥāfiz al-Mulk, Ḥāfiz Raḥmāt Khān Baṛesī aw dā haghah koranay
# ocloc_id: 213595383
# URL: http://www.worldcat.org/oclc/213595383
# ===========
#
# 70
# Title: Da Ṡamkano Miyā ʻUmar
# ocloc_id: 29632123
# URL: http://www.worldcat.org/oclc/29632123
# ===========
#
# 71
# Title: Milī atal Ghāzī Wazīr Muḥammad Akbar Khān
# ocloc_id: 214280810
# URL: http://www.worldcat.org/oclc/214280810
# ===========
#
# 72
# Title: Da Paṭe khazāne farhang
# ocloc_id: 25063901
# URL: http://www.worldcat.org/oclc/25063901
# ===========
#
# 73
# Title: مصر تتحدث العربية : لمحة عن قيمة وطن وشرف إنتماء /
# Miṣr tataḥaddath al-ʻArabīyah : Lamḥah ʻan qīmat waṭan wa-sharaf intimāʼ
# ocloc_id: 901988624
# URL: http://www.worldcat.org/oclc/901988624
# ===========
#
# 74
# Title: د تودو وينو حمام افغانستان شو : شعرى غونډه /
# Da todo wyno ḥamām Afghānistān sho : shʻirī ghwanḍah
# ocloc_id: 727048071
# URL: http://www.worldcat.org/oclc/727048071
# ===========
#
# 75
# Title: شعر جوان کابل : مجموعه شعر /
# Shiʻr-i javān-i Kābul : majmūʻah-i shiʻr
# ocloc_id: 761468706
# URL: http://www.worldcat.org/oclc/761468706
# ===========
#
# 76
# Title: Lughawī ṡeṛanah
# ocloc_id: 420583350
# URL: http://www.worldcat.org/oclc/420583350
# ===========
#
# 77
# Title: Gitʼānjalī
# ocloc_id: 6501168
# URL: http://www.worldcat.org/oclc/6501168
# ===========
#
# 78
# Title: Da Kandahār yādāṣhtūnah
# ocloc_id: 214280575
# URL: http://www.worldcat.org/oclc/214280575
# ===========
#
# 79
# Title: أحاديث الموطأ وذكر اتفاق الرواة عن مالك واختلافهم فيه وزيادتهم ونقصانهم /
# Aḥādīth al-Muwaṭṭaʼ wa-dhikr ittifāq al-ruwāh ʻan Mālik wa-ikhtilāfihim fīh wa-ziyādatihim wa-nuqṣānihim
# ocloc_id: 213912196
# URL: http://www.worldcat.org/oclc/213912196
# ===========
#
# 80
# Title: المحبة لله سبحانه /
# al-Maḥabbah lillāh subḥānah
# ocloc_id: 60521989
# URL: http://www.worldcat.org/oclc/60521989
# ===========
#
# 81
# Title: Tāj
# ocloc_id: 6529259
# URL: http://www.worldcat.org/oclc/6529259
# ===========
#
# 82
# Title: Gulshan-i Roh
# ocloc_id: 20868279
# URL: http://www.worldcat.org/oclc/20868279
# ===========
#
# 83
# Title: Da Ḥaji Jumʻah Bārakzay dīwān
# ocloc_id: 20484668
# URL: http://www.worldcat.org/oclc/20484668
# ===========
#
# 84
# Title: حبذا الأرض تقول : شعر /
# Ḥabbadhā al-arḍ yaqūl : shiʻr
# ocloc_id: 680229818
# URL: http://www.worldcat.org/oclc/680229818
# ===========
#
# 85
# Title: Da Qiṣṣah Khwānī da khūnray peshay reporṭ
# ocloc_id: 36064459
# URL: http://www.worldcat.org/oclc/36064459
# ===========
#
# 86
# Title: Dar bārah-ź Ẓafarnāmah-i Akbarī va nāẓim-i ān
# ocloc_id: 30531840
# URL: http://www.worldcat.org/oclc/30531840
# ===========
#
# 87
# Title: Adabı̄ nas̲runah ;Da benawā yād ;Da kārnāmu mermanay ;Da glu geḍi
# ocloc_id: 872000654
# URL: http://www.worldcat.org/oclc/872000654
# ===========
#
# 88
# Title: خىابانهاى سرگردان : مجموعه شعر /
# Khiyābānhā-yi sargardān : majmūʻah-i shiʻr
# ocloc_id: 682957191
# URL: http://www.worldcat.org/oclc/682957191
# ===========
#
# 89
# Title: Wūjūh lā tunsá : burtrayhāt ʻann mushakhkhaṣātīyat Miṣr
# ocloc_id: 951443878
# URL: http://www.worldcat.org/oclc/951443878
# ===========
#
# 90
# Title: Da Ahmad Shāh Bābā da ashʻāro Pushto sharh
# ocloc_id: 25777178
# URL: http://www.worldcat.org/oclc/25777178
# ===========
# 91
# Title: Da Dawlat Lwāṇī Dīwān
# ocloc_id: 6495986
# URL: http://www.worldcat.org/oclc/6495986
# ===========
#
# 92
# Title: ارمغان قدردان /
# Armaghān-i Qadrdān
# ocloc_id: 234217501
# URL: http://www.worldcat.org/oclc/234217501
# ===========
#
# 93
# Title: الفبايى بر لوح اين زمانه : نقد و يادداشتهاى ادبى /
# Alifbāyī bar lawḥ-i īn zamānah : naqd va yāddāshtʹhā-yi adabī
# ocloc_id: 837622907
# URL: http://www.worldcat.org/oclc/837622907
# ===========
#
# 94
# Title: بر‌اندازى حزب اتحاد و زندانيان استبداد /
# Barʹandāzī-i Ḥizb-i Ittiḥād va zindāniyān-i istibdād
# ocloc_id: 726695623
# URL: http://www.worldcat.org/oclc/726695623
# ===========
#
# 95
# Title: فرهنگ در روابط بىن الملل : مجموعه مقالات سمىنار علمى /
# Farhang dar ravābiṭ-i bayn al-milal : majmūʻh-i maqālāt-i simīnār-i ʻilmī
# ocloc_id: 904024259
# URL: http://www.worldcat.org/oclc/904024259
# ===========
#
# 96
# Title: ‏مقدمه‌اى بر بر‌رسى گسستهاى اجتماعى افغانستان‏
# Muqaddamahʹī bar barʹrasī -i gusasathā-yi ijtimāʻī-i Afghānistān
# ocloc_id: 881721862
# URL: http://www.worldcat.org/oclc/881721862
# ===========
#
# 97
# Title: الذات الالهية بين الاسلام والنصرانية /
# al-Dhāt al-ilahīyah bayna al-Islām wa-al-Naṣrānīyah
# ocloc_id: 714913977
# URL: http://www.worldcat.org/oclc/714913977
# ===========
#
# 98
# Title: بحر الهدايت : اردو شرح مسلّم الثبوت /
# Baḥrulhidāyat : Urdū sharḥ Musallam al-S̲ubūt
# ocloc_id: 609866650
# URL: http://www.worldcat.org/oclc/609866650
# ===========
#
# 99
# Title: Be laso ṣhaẓah
# ocloc_id: 678544939
# URL: http://www.worldcat.org/oclc/678544939
# ===========
#
# 100
# Title: مبارزۀ خونين مردم افغانستان در راه آزادى /
# Mubārazah-ʼi khūnīn-i mardum-i Afghānistān dar rāh-i āzādī
# ocloc_id: 45352815
# URL: http://www.worldcat.org/oclc/45352815
# ===========
#
# 101
# Title: با چراغى در دست : شعر افغانستان ضد طالب‌فکرى /
# Bā chirāghī dar dast : shiʻr-i Afghānistān z̤idd-i ṭālibʹfikrī
# ocloc_id: 934382823
# URL: http://www.worldcat.org/oclc/934382823
# ===========
#
# 102
# Title: دستنبو
# Dastanbū
# ocloc_id: 14927690
# URL: http://www.worldcat.org/oclc/14927690
# ===========
#
# 103
# Title: طبقات المكثرين من رواية الحديث /
# Ṭabaqāt al-mukthirīn min riwāyat al-Ḥadīth
# ocloc_id: 57601200
# URL: http://www.worldcat.org/oclc/57601200
# ===========
#
# 104
# Title: قواعد العلل وقرائن الترجيح /
# Qawāʻid al-ʻilal wa-qarāʼin al-tarjīḥ
# ocloc_id: 60801056
# URL: http://www.worldcat.org/oclc/60801056
# ===========
#
# 105
# Title: Aḥmad shāhī shahnāmah
# ocloc_id: 423390423
# URL: http://www.worldcat.org/oclc/423390423
# ===========
#
# 106
# Title: Kitāb Musallam al-thubūt ...
# ocloc_id: 427617286
# URL: http://www.worldcat.org/oclc/427617286
# ===========
#
# 107
# Title: گفتمان‌هاى مقايسه‌اى اسلام و دموکراسى : با تأکيد بر افغانستان /
# Guftimānʹhā-yi muqāyasahʹī Islām va Dimūkrāsī : bā taʼkīd bar Afghānistān
# ocloc_id: 917888957
# URL: http://www.worldcat.org/oclc/917888957
# ===========
#
# 108
# Title: Tazkirah-i s︠h︡āh Ṭahmāsb : s︠h︡arḥ-i vaqāyiʻ va ʼaḥvālāt-i zindagānī-i s︠h︡āh Ṭahmāsb-i Ṣafavī bi-qalam-i k︠h︡ūdas︠h︡
# ocloc_id: 40579364
# URL: http://www.worldcat.org/oclc/40579364
# ===========
#
# 109
# Title: Ḥayāt-i Afghānī
# ocloc_id: 43512792
# URL: http://www.worldcat.org/oclc/43512792
# ===========
#
# 110
# Title: al-Mustaṣfá min ʻilm al-uṣūl
# ocloc_id: 78649555
# URL: http://www.worldcat.org/oclc/78649555
# ===========
#
# ./urdu_cards_pages/1032971/U2_for_Transkribus/page/0040_24568000444.xml
# ./urdu_cards_pages/1032971/U2_for_Transkribus/page/0034_24567999574.xml
# ===========
# CARD TRANSCRIPTION
# Shelfmark = 14112. h. 21
# Author = NASIM, B.A.
# Title = EHUNI TOLAH
#
# **PARAMETERS USED ON WORLDCAT**
# Query parameters: surname
# N. results: 24,934
# ===========
#
# RESULTS (limited to max 100):
# 1
# Title: Developments in fiber-reinforced polymer (FRP) composites for civil engineering
# ocloc_id: 861536584
# URL: http://www.worldcat.org/oclc/861536584
# ===========
#
# 2
# Title: Quantitative Risk Assessment (QRA) for Natural Hazards.
# ocloc_id: 922966208
# URL: http://www.worldcat.org/oclc/922966208
# ===========
#
# 3
# Title: Kashidakari.
# ocloc_id: 60306322
# URL: http://www.worldcat.org/oclc/60306322
# ===========
#
# 4
# Title: Disaster Risk Assessment and Mitigation : Arrival of the South Asia Tsunami Wave in Thailand.
# ocloc_id: 956633134
# URL: http://www.worldcat.org/oclc/956633134
# ===========
#
# 5
# Title: Science and Muslim societies
# ocloc_id: 26787436
# URL: http://www.worldcat.org/oclc/26787436
# ===========
#
# 6
# Title: Khak aur khun
# ocloc_id: 755109237
# URL: http://www.worldcat.org/oclc/755109237
# ===========
#
# 7
# Title: Economics of irrigation rates : A study in Punjab and Uttar Pradesh
# ocloc_id: 1141492202
# URL: http://www.worldcat.org/oclc/1141492202
# ===========
#
# 8
# Title: Financing Pakistan's development in the 1990s
# ocloc_id: 782164419
# URL: http://www.worldcat.org/oclc/782164419
# ===========
#
# 9
# Title: Oral Signs of Systemic Disease
# ocloc_id: 1203318404
# URL: http://www.worldcat.org/oclc/1203318404
# ===========
#
# 10
# Title: Sensitivity of modal parameters of an offshore wind turbine to operational and envrionmental factors : a numerical study, preprint
# ocloc_id: 1334673193
# URL: http://www.worldcat.org/oclc/1334673193
# ===========
#
# 11
# Title: Islamic art of India
# ocloc_id: 808597903
# URL: http://www.worldcat.org/oclc/808597903
# ===========
#
# 12
# Title: Migración y trans-culturación : enfoque psicosocial y psicoanalítico
# ocloc_id: 655837078
# URL: http://www.worldcat.org/oclc/655837078
# ===========
#
# 13
# Title: Observing by hand : sketching the nebulae in the nineteenth century
# ocloc_id: 967264105
# URL: http://www.worldcat.org/oclc/967264105
# ===========
#
# 14
# Title: Islam's political culture : religion and politics in predivided Pakistan
# ocloc_id: 1129466273
# URL: http://www.worldcat.org/oclc/1129466273
# ===========
#
# 15
# Title: The astronomer's chair : a visual and cultural history
# ocloc_id: 1201695428
# URL: http://www.worldcat.org/oclc/1201695428
# ===========
#
# 16
# Title: Islam and political attitudes in Pakistan and Bangla Desh : a thematic and quantitative approach
# ocloc_id: 61538567
# URL: http://www.worldcat.org/oclc/61538567
# ===========
#
# 17
# Title: Notieren, Skizzieren Schreiben und Zeichnen als Verfahren des Entwurfs
# ocloc_id: 1157298307
# URL: http://www.worldcat.org/oclc/1157298307
# ===========
#
# 18
# Title: Buddhist painting in Gandhara
# ocloc_id: 935382013
# URL: http://www.worldcat.org/oclc/935382013
# ===========
#
# 19
# Title: SDG15 - life on land towards effective biodiversity management
# ocloc_id: 1286179738
# URL: http://www.worldcat.org/oclc/1286179738
# ===========
#
# 20
# Title: Challenges of affordable housing finance in IDB member countries using Islamic modes
# ocloc_id: 885159713
# URL: http://www.worldcat.org/oclc/885159713
# ===========
#
# 21
# Title: Geneva Conventions and the Pakistani prisoners of war.
# ocloc_id: 828896821
# URL: http://www.worldcat.org/oclc/828896821
# ===========
#
# 22
# Title: Judgements on the constitution, rule of law, and martial law in Pakistan
# ocloc_id: 832312824
# URL: http://www.worldcat.org/oclc/832312824
# ===========
#
# 23
# Title: An evening with Javed Akhtar & Ifti Nasim.
# ocloc_id: 37995735
# URL: http://www.worldcat.org/oclc/37995735
# ===========
#
# 24
# Title: Wees mooi : gedichten van Nasim Khaksar
# ocloc_id: 753427806
# URL: http://www.worldcat.org/oclc/753427806
# ===========
#
# 25
# Title: Community voices : tackling inequity through a community based initiative on the social determinants of health : Part II
# ocloc_id: 319677421
# URL: http://www.worldcat.org/oclc/319677421
# ===========
#
# 26
# Title: Adult learners' preferred methods of learning preventative heart disease care
# ocloc_id: 973883343
# URL: http://www.worldcat.org/oclc/973883343
# ===========
#
# 27
# Title: Assessment of volatile metabolites for in situ detection of fungal decay of wood
# ocloc_id: 1018944475
# URL: http://www.worldcat.org/oclc/1018944475
# ===========
#
# 28
# Title: Understanding the Nakba : an insight into the plight of the Palestinians
# ocloc_id: 874115756
# URL: http://www.worldcat.org/oclc/874115756
# ===========
#
# 29
# Title: Voices of multicultural youth : impact of urban neighbourhood on health and well-being
# ocloc_id: 1059240737
# URL: http://www.worldcat.org/oclc/1059240737
# ===========
#
# 30
# Title: Dr. Akhtar Hameed Khan, pioneer of microcredit and guru of rural development : a tribute on his 13th death anniversary
# ocloc_id: 1006032855
# URL: http://www.worldcat.org/oclc/1006032855
# ===========
# 31
# Title: Optoelectronic Properties of Organic Semiconductors : Charge Generation and Recombination in Next-Generation Photovoltaic Devices
# ocloc_id: 1308494884
# URL: http://www.worldcat.org/oclc/1308494884
# ===========
#
# 32
# Title: Inferring Social Relations from Online and Communication Networks
# ocloc_id: 1005514951
# URL: http://www.worldcat.org/oclc/1005514951
# ===========
#
# 33
# Title: Mahatma Gandhi & my grandfather, Allama Mashriqi : a groundbreaking narrative of India's partition
# ocloc_id: 1001427739
# URL: http://www.worldcat.org/oclc/1001427739
# ===========
#
# 34
# Title: Hidden facts behind British India's freedom : a scholarly look into Allama Mashraqi and Quaid-e-Azam's political conflict
# ocloc_id: 171167114
# URL: http://www.worldcat.org/oclc/171167114
# ===========
#
# 35
# Title: Advanced simulation of an adaptive lower limb prosthesis
# ocloc_id: 1184387432
# URL: http://www.worldcat.org/oclc/1184387432
# ===========
#
# 36
# Title: Exploring the link between neighbourhood and newcomer immigrant health : a qualitative study
# ocloc_id: 695536430
# URL: http://www.worldcat.org/oclc/695536430
# ===========
#
# 37
# Title: Pakistans freedom & Allama Mashriqi : statements, letters, chronology of Khaksar Tehrik (movement) period : Mashriqis birth to 1947
# ocloc_id: 58386804
# URL: http://www.worldcat.org/oclc/58386804
# ===========
#
# 38
# Title: New Solar Homes Partnership guidebook : commission guidebook
# ocloc_id: 1029565900
# URL: http://www.worldcat.org/oclc/1029565900
# ===========
#
# 39
# Title: Isogeometric analysis of fiber-reinforced materials scale adaptivity and delamination
# ocloc_id: 895312905
# URL: http://www.worldcat.org/oclc/895312905
# ===========
#
# 40
# Title: Phase-locked loop with adaptive supply noise cancellation.
# ocloc_id: 234120115
# URL: http://www.worldcat.org/oclc/234120115
# ===========
#
# 41
# Title: Exploring the Link Between Neighbourhood and Newcomer Immigrant Health : St. James Town Initiative.
# ocloc_id: 927203086
# URL: http://www.worldcat.org/oclc/927203086
# ===========
#
# 42
# Title: Sensitivity of emotionally disturbed and emotionally non-disturbed elementary school children to emotional meanings of facial expressions
# ocloc_id: 28176774
# URL: http://www.worldcat.org/oclc/28176774
# ===========
#
# 43
# Title: Smart Meter Networks: Intrusion Detection System by Design
# ocloc_id: 882491771
# URL: http://www.worldcat.org/oclc/882491771
# ===========
#
# 44
# Title: Community voices : tackling inequity through a community based initiative on the social determinants of health
# ocloc_id: 1086931921
# URL: http://www.worldcat.org/oclc/1086931921
# ===========
#
# 45
# Title: Inhibition of HIF-1α enhances anti-tumor effects of dendritic cell-based vaccination in a mouse model of breast cancer
# ocloc_id: 1186845961
# URL: http://www.worldcat.org/oclc/1186845961
# ===========
#
# 46
# Title: Optimization of the mechanical properties of the metallic components by micro-surface structuring and the improvement of the fatigue behavior
# ocloc_id: 1245363276
# URL: http://www.worldcat.org/oclc/1245363276
# ===========
#
# 47
# Title: Follicular development and fertility in beef cows
# ocloc_id: 1316836623
# URL: http://www.worldcat.org/oclc/1316836623
# ===========
#
# 48
# Title: Actinobacteria and Myxobacteria isolated from freshwater snails and other uncommon Iranian habitats, their taxonomy and secondary metabolism
# ocloc_id: 1256581416
# URL: http://www.worldcat.org/oclc/1256581416
# ===========
#
# 49
# Title: Government & politics in the U.S.S.R.
# ocloc_id: 1131583524
# URL: http://www.worldcat.org/oclc/1131583524
# ===========
#
# 50
# Title: Integration of concept mapping and photovoice : understanding immigrant perceptions of neighbourhood influences on health
# ocloc_id: 1059213359
# URL: http://www.worldcat.org/oclc/1059213359
# ===========
#
# 51
# Title: Characterization of probiotic Lactobacillus spp. isolates from commercial fermented milks.
# ocloc_id: 1064900102
# URL: http://www.worldcat.org/oclc/1064900102
# ===========
#
# 52
# Title: Nanoscale mechanics of ductile interphases in solid solution directionally solidified eutectic composites.
# ocloc_id: 368184396
# URL: http://www.worldcat.org/oclc/368184396
# ===========
#
# 53
# Title: Hydrologic responses to fuelwood harvest and slash disposal on a pinyon-juniper dominated grassland site in the Gila National Forest, New Mexico
# ocloc_id: 24452125
# URL: http://www.worldcat.org/oclc/24452125
# ===========
#
# 54
# Title: The impact of diabetes patients' trust in their physicians on medical care & health-producing activities
# ocloc_id: 429516324
# URL: http://www.worldcat.org/oclc/429516324
# ===========
#
# 55
# Title: Hollywoof!
# ocloc_id: 630535445
# URL: http://www.worldcat.org/oclc/630535445
# ===========
#
# 56
# Title: New Solar Homes Partnership draft guidebook
# ocloc_id: 1029571763
# URL: http://www.worldcat.org/oclc/1029571763
# ===========
#
# 57
# Title: Bit patterned media with composite structure for microwave assisted magnetic recording
# ocloc_id: 945081123
# URL: http://www.worldcat.org/oclc/945081123
# ===========
#
# 58
# Title: The effects of urban expansion on spatial and socioeconomic patterns of the peri-urban areas: a case study of Isfahan city, Iran
# ocloc_id: 1077596425
# URL: http://www.worldcat.org/oclc/1077596425
# ===========
#
# 59
# Title: The light of Golra Sharif
# ocloc_id: 39724099
# URL: http://www.worldcat.org/oclc/39724099
# ===========
#
# 60
# Title: My African sojourns : a UN diplomat's experiences of working in the strife-torn countries of Africa
# ocloc_id: 964359540
# URL: http://www.worldcat.org/oclc/964359540
# ===========
#
# 61
# Title: Arms race in the Middle East
# ocloc_id: 3844991
# URL: http://www.worldcat.org/oclc/3844991
# ===========
#
# 62
# Title: New Solar Homes Partnership draft guidebook
# ocloc_id: 759524510
# URL: http://www.worldcat.org/oclc/759524510
# ===========
#
# 63
# Title: Allama Mashriqi & Dr. Akhtar Hameed Khan : two legends of Pakistan
# ocloc_id: 54913945
# URL: http://www.worldcat.org/oclc/54913945
# ===========
#
# 64
# Title: Biodiversity in the floodplain ecosystem of Bera, Santhia and Sujanagar upazilas of Pabna district in Bangladesh
# ocloc_id: 900684171
# URL: http://www.worldcat.org/oclc/900684171
# ===========
#
# 65
# Title: Export housewares, gifts & decorative accessories to the United States of America
# ocloc_id: 71222761
# URL: http://www.worldcat.org/oclc/71222761
# ===========
#
# 66
# Title: Affective meanings of facial expressions : a study of emotionally disturbed and non-disturbed children
# ocloc_id: 4433630
# URL: http://www.worldcat.org/oclc/4433630
# ===========
#
# 67
# Title: Hydrogen production by desulfurococcus fermentans
# ocloc_id: 988133085
# URL: http://www.worldcat.org/oclc/988133085
# ===========
#
# 68
# Title: Fertilizer Radionuclide pollution & Potential Health Hazards Fertilizer Pollution & Risk Assessment on Human Health
# ocloc_id: 863877071
# URL: http://www.worldcat.org/oclc/863877071
# ===========
#
# 69
# Title: Some results relating the behaviour of Fourier transforms near the origin and at infinity
# ocloc_id: 2024024
# URL: http://www.worldcat.org/oclc/2024024
# ===========
#
# 70
# Title: Suicide in Literature: A Study of Suicidal Authors' Works and Life
# ocloc_id: 916062062
# URL: http://www.worldcat.org/oclc/916062062
# ===========
#
# 71
# Title: Optoelectronic Properties of Organic Semiconductors : Charge Generation and Recombination in Next-Generation Photovoltaic Devices
# ocloc_id: 1304488303
# URL: http://www.worldcat.org/oclc/1304488303
# ===========
#
# 72
# Title: Pakistan's birth & Allama Mashraqi : chronology & statements, period, 1947-1963
# ocloc_id: 254445306
# URL: http://www.worldcat.org/oclc/254445306
# ===========
#
# 73
# Title: Women in Eugene O'Neill's Plays
# ocloc_id: 916209773
# URL: http://www.worldcat.org/oclc/916209773
# ===========
#
# 74
# Title: Allama Mashriqi narrowly escapes the gallows : court proceedings of an unpardonable crime against the man who led the freedom of the Indian subcontinent
# ocloc_id: 950753522
# URL: http://www.worldcat.org/oclc/950753522
# ===========
#
# 75
# Title: Optoelectronic Properties of Organic Semiconductors : Charge Generation and Recombination in Next-Generation Photovoltaic Devices
# ocloc_id: 1330581587
# URL: http://www.worldcat.org/oclc/1330581587
# ===========
#
# 76
# Title: Pakistani idare,
# ocloc_id: 51176531
# URL: http://www.worldcat.org/oclc/51176531
# ===========
#
# 77
# Title: Parliamentary government in Pakistan.
# ocloc_id: 555175684
# URL: http://www.worldcat.org/oclc/555175684
# ===========
#
# 78
# Title: Computational analysis of parameter uncertainties in a two-dimensional mixed-culture biofilm model
# ocloc_id: 828058715
# URL: http://www.worldcat.org/oclc/828058715
# ===========
#
# 79
# Title: Impacts of massively parallel sequencing for genetic diagnosis of neuromuscular disorders
# ocloc_id: 1196505919
# URL: http://www.worldcat.org/oclc/1196505919
# ===========
#
# 80
# Title: Next generation sequencing for molecular diagnosis of neuromuscular diseases
# ocloc_id: 1190274868
# URL: http://www.worldcat.org/oclc/1190274868
# ===========
# 81
# Title: Graphene oxide covalently functionalized with an organic superbase as highly efficient and durable nanocatalyst for green Michael addition reaction
# ocloc_id: 1188493110
# URL: http://www.worldcat.org/oclc/1188493110
# ===========
#
# 82
# Title: The British political system.
# ocloc_id: 576053722
# URL: http://www.worldcat.org/oclc/576053722
# ===========
#
# 83
# Title: Reaching the minimum ideal in a finite semigroup
# ocloc_id: 1187942231
# URL: http://www.worldcat.org/oclc/1187942231
# ===========
#
# 84
# Title: Risk of cancer in 10 - 19 mm endoscopically detected colorectal lesions
# ocloc_id: 1190218758
# URL: http://www.worldcat.org/oclc/1190218758
# ===========
#
# 85
# Title: Community voices : tackling inequity through a community based initiative on the social determinants of health : Part I
# ocloc_id: 1331427709
# URL: http://www.worldcat.org/oclc/1331427709
# ===========
#
# 86
# Title: How network monitoring and reinforcement learning can improve tcp fairness in wireless multi-hop networks
# ocloc_id: 1188135173
# URL: http://www.worldcat.org/oclc/1188135173
# ===========
#
# 87
# Title: POEM in the Treatment of Esophageal Disorders
# ocloc_id: 1187271303
# URL: http://www.worldcat.org/oclc/1187271303
# ===========
#
# 88
# Title: Metabolomics reveals the role of endocannabinoid system in modulating obesity-associated inflammation in adipose tissue
# ocloc_id: 1159310928
# URL: http://www.worldcat.org/oclc/1159310928
# ===========
#
# 89
# Title: Removal of pollutants (COD, TSS, and NO3 −) from textile effluent using Gambusia fish and Phragmites australis in constructed wetlands
# ocloc_id: 1189257292
# URL: http://www.worldcat.org/oclc/1189257292
# ===========
#
# 90
# Title: Impact of different geometric shapes on drying kinetics and textural characteristics of apples at temperatures above 100 °C
# ocloc_id: 1196740692
# URL: http://www.worldcat.org/oclc/1196740692
# ===========
#
# 91
# Title: Experimental study on the heat-affected zone of glass substrate machined by electrochemical discharge machining (ECDM) process
# ocloc_id: 1187611393
# URL: http://www.worldcat.org/oclc/1187611393
# ===========
#
# 92
# Title: Impact of socio-economic and demographic variables on human fertility : impact of socio-economic and demographic variables on human fertility behaviour : a multivariate statistical analysis
# ocloc_id: 876322354
# URL: http://www.worldcat.org/oclc/876322354
# ===========
#
# 93
# Title: PCOS, A Complicated Puzzle Insulin resistance, carbohydrate metabolism, anovulation, Infertility
# ocloc_id: 864018420
# URL: http://www.worldcat.org/oclc/864018420
# ===========
#
# 94
# Title: Numerical Simulation on the Origin of Solidification Cracking in Laser Welded Thick-Walled Structures
# ocloc_id: 1190480159
# URL: http://www.worldcat.org/oclc/1190480159
# ===========
#
# 95
# Title: Loads Simulator System for Testing and Qualification of Flight Actuators
# ocloc_id: 1154251387
# URL: http://www.worldcat.org/oclc/1154251387
# ===========
#
# 96
# Title: Evaluation of endovascular repair of abdominal aortic aneurysms
# ocloc_id: 504889344
# URL: http://www.worldcat.org/oclc/504889344
# ===========
#
# 97
# Title: Pakistan
# ocloc_id: 772751648
# URL: http://www.worldcat.org/oclc/772751648
# ===========
#
# 98
# Title: Protective Role of Zinc and Magnesium against Cadmium Nephrotoxicity in Male Wistar Rats
# ocloc_id: 1185883976
# URL: http://www.worldcat.org/oclc/1185883976
# ===========
#
# 99
# Title: A Marginalized Overdispersed Location Scale Model for Clustered Ordinal Data
# ocloc_id: 1187680481
# URL: http://www.worldcat.org/oclc/1187680481
# ===========
#
# 100
# Title: Record of creative work
# ocloc_id: 1066133344
# URL: http://www.worldcat.org/oclc/1066133344
# ===========
#
# 101
# Title: Importing gifts, housewares & decorative accessories from Hong Kong
# ocloc_id: 70236589
# URL: http://www.worldcat.org/oclc/70236589
# ===========
#
# 102
# Title: Familial relative risks for breast cancer by pathological subtype: a population-based cohort study
# ocloc_id: 1185657276
# URL: http://www.worldcat.org/oclc/1185657276
# ===========
#
# 103
# Title: Subfilter scale combustion modelling for large eddy simulation of turbulent premixed flames.
# ocloc_id: 976462414
# URL: http://www.worldcat.org/oclc/976462414
# ===========
#
# 104
# Title: Integration of concept mapping and photovoice : understanding immigrant perceptions of neighbourhood influences on health
# ocloc_id: 1331425754
# URL: http://www.worldcat.org/oclc/1331425754
# ===========
#
# 105
# Title: Structure and growth of core-shell nanoprecipitates in Al-Er-Sc-Zr-V-Si high-temperature alloys
# ocloc_id: 1189114618
# URL: http://www.worldcat.org/oclc/1189114618
# ===========
#
# 106
# Title: Anisotropic charged physical models with generalized polytropic equation of state
# ocloc_id: 1187656628
# URL: http://www.worldcat.org/oclc/1187656628
# ===========
#
# 107
# Title: The Effectiveness of SMS Reminders on Appointment Attendance: a Meta-Analysis
# ocloc_id: 1185982948
# URL: http://www.worldcat.org/oclc/1185982948
# ===========
#
# 108
# Title: Fatwâ : its role in Sharîʹah and contemporary society with South African case studies
# ocloc_id: 47107672
# URL: http://www.worldcat.org/oclc/47107672
# ===========
#
# 109
# Title: 11+ success for CEM. Practice test papers. Get ahead
# ocloc_id: 1257971961
# URL: http://www.worldcat.org/oclc/1257971961
# ===========
#
# 110
# Title: Constituent Factors of Learning Environment of Adult Learners
# ocloc_id: 721264135
# URL: http://www.worldcat.org/oclc/721264135
# ===========
#
# ./urdu_cards_pages/1032971/U2_for_Transkribus/page/0037_24568000074.xml
# ===========
# CARD TRANSCRIPTION
# Shelfmark = 14109. a. 213.
# Author = 'ABD al-WAHID, Dr.
# Title = KHULAFA-I-RASHIDIN
#
# **PARAMETERS USED ON WORLDCAT**
# Query parameters: surname
# N. results: 5,545
# ===========
#
# RESULTS (limited to max 100):
# 1
# Title: المعجب في تلخيص أخبار المغرب /
# al-Mu'jib fī talkhīṣ akhbār al-Maghrib
# ocloc_id: 936409644
# URL: http://www.worldcat.org/oclc/936409644
# ===========
#
# 2
# Title: المجيد في إعجاز القرآن المجيد /
# ocloc_id: 956908407
# URL: http://www.worldcat.org/oclc/956908407
# ===========
#
# 3
# Title: al- Kāmil fī ʼt-tārīh̲ Vol. 5 [Annos H. 96-154 continens, ad fidem codicum Londinensium et Parisinorum
# ocloc_id: 256497249
# URL: http://www.worldcat.org/oclc/256497249
# ===========
#
# 4
# Title: All faces but mine : the poetry of Samih al-Qasim
# ocloc_id: 929784206
# URL: http://www.worldcat.org/oclc/929784206
# ===========
#
# 5
# Title: al- Kāmil fi 't-tārīḫ. 11. (1979 = 1399 [islam. Zeit]). - 585 S.
# ocloc_id: 631126839
# URL: http://www.worldcat.org/oclc/631126839
# ===========
#
# 6
# Title: Šarḥ fatḥ al-qādir ʿala 'l-hidāya : šarḥ bidāya al-mubtadī 1
# ocloc_id: 1075175295
# URL: http://www.worldcat.org/oclc/1075175295
# ===========
#
# 7
# Title: The Muslim conquest and settlement of North Africa and Spain
# ocloc_id: 1153998841
# URL: http://www.worldcat.org/oclc/1153998841
# ===========
#
# 8
# Title: كتاب السم القاتل في أمعاء الفاسق المضل الجاهل /
# Kitāb al-Summ al-qātil fī am'ā' al-fāsiq al-muḍill al-jāhil
# ocloc_id: 1028996623
# URL: http://www.worldcat.org/oclc/1028996623
# ===========
#
# 9
# Title: Modern Arabic poetry : an anthology
# ocloc_id: 15132314
# URL: http://www.worldcat.org/oclc/15132314
# ===========
#
# 10
# Title: al- Kāmil fi 't-tārīḫ. 9. (1979 = 1399 [islam. Zeit]). - 676 S.
# ocloc_id: 631126811
# URL: http://www.worldcat.org/oclc/631126811
# ===========
#
# 11
# Title: al-Ittiǧāḥāt wa-'l-ḥarakāt fi 'š-šiʻr al-ʻarabī al-ḥadīt
# ocloc_id: 254339097
# URL: http://www.worldcat.org/oclc/254339097
# ===========
#
# 12
# Title: In memoriam René Guénon
# ocloc_id: 492100730
# URL: http://www.worldcat.org/oclc/492100730
# ===========
#
# 13
# Title: al- Kāmil fi 't-tārīḫ. 4. (1979 = 1399 [islam. Zeit]). - 602 S.
# ocloc_id: 631126712
# URL: http://www.worldcat.org/oclc/631126712
# ===========
#
# 14
# Title: تيسير العلام : شرح عمدة الاحكام /
# Taysīr al-ʻallām : sharḥ ʻUmdat al-aḥkām
# ocloc_id: 82145533
# URL: http://www.worldcat.org/oclc/82145533
# ===========
#
# 15
# Title: ديوان عبد الغفار الأخرس /
# Dīwān 'Abd al-Ghaffār al-Akhras
# ocloc_id: 900891366
# URL: http://www.worldcat.org/oclc/900891366
# ===========
#
# 16
# Title: التبيان في علم البيان المطلع على إعجاز القرآن /
# al-Tibyān fī ʻilm al-bayān al-muṭṭaliʻ ʻalá iʻjāj al-Qurʼān
# ocloc_id: 1232235469
# URL: http://www.worldcat.org/oclc/1232235469
# ===========
#
# 17
# Title: al- Babbaġā' : ʻAbd-al-Wāḥid Ibn-Naṣr al-Mah̲zūmī - ḥayātuhu, dīwānuhu, rasā'iluhu, qiṣaṣuhu
# ocloc_id: 163755665
# URL: http://www.worldcat.org/oclc/163755665
# ===========
#
# 18
# Title: الكامل في التاريخ /
# al-Kāmil fī al-tārikh
# ocloc_id: 1028050401
# URL: http://www.worldcat.org/oclc/1028050401
# ===========
#
# 19
# Title: Kitāb al- Manāqib wa-'l-mat̲ālib
# ocloc_id: 166003121
# URL: http://www.worldcat.org/oclc/166003121
# ===========
#
# 20
# Title: Muqaddimat Ibn Khaldūn
# ocloc_id: 69669848
# URL: http://www.worldcat.org/oclc/69669848
# ===========
# 21
# Title: Muqaddimat Ibn Khaldūn
# ocloc_id: 69669848
# URL: http://www.worldcat.org/oclc/69669848
# ===========
#
# 22
# Title: Al-Lughah wa-al-mujtama'.
# ocloc_id: 977846446
# URL: http://www.worldcat.org/oclc/977846446
# ===========
#
# 23
# Title: al-Wafā bi-aḥwāl al-Muṣṭafā
# ocloc_id: 255721346
# URL: http://www.worldcat.org/oclc/255721346
# ===========
#
# 24
# Title: مجموع فيه : مشيخة أبي طاهر ابن أبي الصقر /
# Majmūʻ fīh : Mashīkhat Abī Ṭāhir ibn Abī al-Ṣaqr
# ocloc_id: 476480345
# URL: http://www.worldcat.org/oclc/476480345
# ===========
#
# 25
# Title: Ḥurr al-riyāḥī : masraḥīyah shiʻrīyah fī thalāthat fuṣūl
# ocloc_id: 644607903
# URL: http://www.worldcat.org/oclc/644607903
# ===========
#
# 26
# Title: Shajar al-durr.
# ocloc_id: 976569674
# URL: http://www.worldcat.org/oclc/976569674
# ===========
#
# 27
# Title: 12 nouvelles d'Arabie Saoudite. Tome 3
# ocloc_id: 1032812067
# URL: http://www.worldcat.org/oclc/1032812067
# ===========
#
# 28
# Title: Kitāb al- Amrāḍ al-kaffārāt wa-'ṭ-ṭibb wa-'r-ruqyāt
# ocloc_id: 165327324
# URL: http://www.worldcat.org/oclc/165327324
# ===========
#
# 29
# Title: Birnamij al-wifaq al-watani fi muwajahat al-'unf al-siyasi wa-al-dini : waqa'i' wa-tawsiyat al-hiwar bayna mukhtalaf al-ittijahat al-siyasiyah wa-al-fikriyah
# ocloc_id: 474261544
# URL: http://www.worldcat.org/oclc/474261544
# ===========
#
# 30
# Title: ٢.
# Al- Iktifāʼ fī maġāzī rasūl Allāh wa-ʼt̲-t̲alāt̲a al-ḫulafāʼ. 2
# ocloc_id: 917521206
# URL: http://www.worldcat.org/oclc/917521206
# ===========
#
# 31
# Title: Al-mu'djib fī talkhīṣ akhbār al-Maghrib
# ocloc_id: 874708906
# URL: http://www.worldcat.org/oclc/874708906
# ===========
#
# 32
# Title: al-'Umda fi al-ahkam fi ma'alim al-halal wa-al-haram
# ocloc_id: 912195432
# URL: http://www.worldcat.org/oclc/912195432
# ===========
#
# 33
# Title: مدائن الوهم : شعر الحداثة والشتات, دراسة نقدية = Unreal cities, Arabic poetry of modernism and the Diaspora
# ocloc_id: 1227969836
# URL: http://www.worldcat.org/oclc/1227969836
# ===========
#
# 34
# Title: The contribution of Spanish Muslims to the European poetry
# ocloc_id: 47805200
# URL: http://www.worldcat.org/oclc/47805200
# ===========
#
# 35
# Title: al- ʻUmda fi 'l-aḥkām fī maʻālim al-ḥalāl ʻan hair al-anām Muḥammad ʻalaihi aṣ-ṣalāt wa-'s-salām
# ocloc_id: 164889957
# URL: http://www.worldcat.org/oclc/164889957
# ===========
#
# 36
# Title: سبل الهدى والرشاد في سيرة خير العباد /
# Subul al-hudá wa-al-rashād fī sīrat Khayr al-ʻIbād
# ocloc_id: 11540880
# URL: http://www.worldcat.org/oclc/11540880
# ===========
#
# 37
# Title: The life of the prophet Muḥammad : a translation of al-Sīra al-Nabawiyya / Vol. IV / reviewed by Muneer Fareed.
# ocloc_id: 772971274
# URL: http://www.worldcat.org/oclc/772971274
# ===========
#
# 38
# Title: 'Abd al-Raḥmān ibn Khaldūn : Hayātahu wa-āthārahu wa-maẓāhir 'abgarīyatihi
# ocloc_id: 63079949
# URL: http://www.worldcat.org/oclc/63079949
# ===========
#
# 39
# Title: الوعى العربي و وحدة مصر و ليبيا /
# al Wa'y al'Arabī wa waḥdat Miṣr wa-Libyā
# ocloc_id: 645343561
# URL: http://www.worldcat.org/oclc/645343561
# ===========
#
# 40
# Title: al- ʻUmda fi 'l-aḥkām fi 'l-ḥalāl wa-'l-ḥarām
# ocloc_id: 165466935
# URL: http://www.worldcat.org/oclc/165466935
# ===========
#
# 41
# Title: Al-Mu'yab fi Taljis Ajbar Al-Magrib / Libro 3.
# ocloc_id: 912029844
# URL: http://www.worldcat.org/oclc/912029844
# ===========
#
# 42
# Title: Diwan Kasayim
# ocloc_id: 912149478
# URL: http://www.worldcat.org/oclc/912149478
# ===========
#
# 43
# Title: غرر الحكم ودرر الكلم : مجموعة من كلمات وحكم الامام علي، عليه السلام /
# Ghurar al-ḥikam wa-durar al-kalim : majmūʻah min kalimāt wa-ḥikam al-Imām ʻAlī
# ocloc_id: 37482116
# URL: http://www.worldcat.org/oclc/37482116
# ===========
#
# 44
# Title: Mencari ketenangan rumahtangga : dengan mengusir syaitan dan memberi laluan kepada para malaikat
# ocloc_id: 849977460
# URL: http://www.worldcat.org/oclc/849977460
# ===========
#
# 45
# Title: L'islam intérieur : la spiritualité universelle dans la religion islamique
# ocloc_id: 860396356
# URL: http://www.worldcat.org/oclc/860396356
# ===========
#
# 46
# Title: The history of the Almohades : preceded by a sketch of the history of Spain, from the time of the conquest till the reign of Yúsof Ibn-Téshúfin and the history of the Almoravides by Abdo-l-Waáhid al-Marrékoshí
# ocloc_id: 1025800223
# URL: http://www.worldcat.org/oclc/1025800223
# ===========
#
# 47
# Title: Kenikmatan syurga & kesengsaraan neraka : berdasarkan hadis-hadis sahih
# ocloc_id: 850060402
# URL: http://www.worldcat.org/oclc/850060402
# ===========
#
# 48
# Title: ال عرب في الأرجنتين : النشوء والتطور /
# Al- ʻArab fī l-Arǧantīn : an-nušūʼ wa-t-taṭauwur
# ocloc_id: 917383813
# URL: http://www.worldcat.org/oclc/917383813
# ===========
#
# 49
# Title: Histoire des Almohades d'Abd el-Wâh'id Merrâkechi
# ocloc_id: 551685435
# URL: http://www.worldcat.org/oclc/551685435
# ===========
#
# 50
# Title: كتاب فضائل الأعمال /
# Kitāb Faḍāʼil al-aʻmāl
# ocloc_id: 40330155
# URL: http://www.worldcat.org/oclc/40330155
# ===========
#
# 51
# Title: Taʼrīḫ al-Andalus al-musammā bi-'l-muʻǧib fī talḫīṣ aḫbār al-Maġrib
# ocloc_id: 258006410
# URL: http://www.worldcat.org/oclc/258006410
# ===========
#
# 52
# Title: شرح فتح القدير /
# Sharḥ Fatḥ al-qadīr
# ocloc_id: 1013543186
# URL: http://www.worldcat.org/oclc/1013543186
# ===========
#
# 53
# Title: al- Wafā bi-aḥwāl al-muṣṭafā. 2
# ocloc_id: 634171009
# URL: http://www.worldcat.org/oclc/634171009
# ===========
#
# 54
# Title: موسوعة علم السياسة /
# Mawsū'at 'ilm al-siyāsah
# ocloc_id: 900892050
# URL: http://www.worldcat.org/oclc/900892050
# ===========
#
# 55
# Title: كتاب فضائل الأعمال /
# Kitāb Faḍā'il al-aʿmāl
# ocloc_id: 1165446497
# URL: http://www.worldcat.org/oclc/1165446497
# ===========
#
# 56
# Title: Al- Itbāʻ wa'l-muzāwaǧa
# ocloc_id: 318016849
# URL: http://www.worldcat.org/oclc/318016849
# ===========
#
# 57
# Title: al-Wazn wa-al-qāfiyah wa-al-shiʻr al-ḥurr : Metre, rhyme and free verse
# ocloc_id: 761373093
# URL: http://www.worldcat.org/oclc/761373093
# ===========
#
# 58
# Title: الحب الحقيقي : رواية /
# al-Ḥubb al-ḥaqīqī : riwāyah
# ocloc_id: 1295590275
# URL: http://www.worldcat.org/oclc/1295590275
# ===========
#
# 59
# Title: الصابئة المندائيون بين الإنصاف والإجحاف /
# al-Ṣābiʼah al-Mandāʼīyūn bayna al-inṣāf wa-al-ijḥāf
# ocloc_id: 1184007458
# URL: http://www.worldcat.org/oclc/1184007458
# ===========
#
# 60
# Title: Paradise : according to Qur'an sunna
# ocloc_id: 1311033886
# URL: http://www.worldcat.org/oclc/1311033886
# ===========
#
# 61
# Title: Paradise : according to Qur'an sunna
# ocloc_id: 1311033886
# URL: http://www.worldcat.org/oclc/1311033886
# ===========
#
# 62
# Title: متن عمدة الاحكام من كلام خير الأنام عليه الصلاه والسلام /
# Matn ʻumdat al-aḥkām min kalām Khayr al-ʼanām ʻalayhi al-ṣalāh wa-al-salām
# ocloc_id: 432734940
# URL: http://www.worldcat.org/oclc/432734940
# ===========
#
# 63
# Title: الديمقراطية وفكرة الدولة /
# al-Dīmuqrāṭīyah wa-fikrat al-dawlah
# ocloc_id: 1255406555
# URL: http://www.worldcat.org/oclc/1255406555
# ===========
#
# 64
# Title: تغريبة احمد الحجري : رواية /
# Taghrībat Aḥmad al-Ḥajarī : riwāyah
# ocloc_id: 71276509
# URL: http://www.worldcat.org/oclc/71276509
# ===========
#
# 65
# Title: The life of Ibn Sina : a critical edition and annotated translation
# ocloc_id: 1062030420
# URL: http://www.worldcat.org/oclc/1062030420
# ===========
#
# 66
# Title: Sifat-sifat syurga dan neraka
# ocloc_id: 957026029
# URL: http://www.worldcat.org/oclc/957026029
# ===========
#
# 67
# Title: al- Īmān fi 'l-qur'ān
# ocloc_id: 163233942
# URL: http://www.worldcat.org/oclc/163233942
# ===========
#
# 68
# Title: الجوانب القانونية لمكافحة الفساد في العراق /
# al-Jawānib al-qānūnīyah li-mukāfaḥat al-fasād fī al-ʻIrāq
# ocloc_id: 1184006109
# URL: http://www.worldcat.org/oclc/1184006109
# ===========
#
# 69
# Title: Sihir dan cara pengubatannya menurut Islam
# ocloc_id: 850888535
# URL: http://www.worldcat.org/oclc/850888535
# ===========
#
# 70
# Title: Al- Madīna al-fāḍila li'l-Fārābī.
# ocloc_id: 313510901
# URL: http://www.worldcat.org/oclc/313510901
# ===========
#
# 71
# Title: إعراب لامية الشنفرى /
# Iʻrāb Lāmīyat al-Shanfará
# ocloc_id: 17887046
# URL: http://www.worldcat.org/oclc/17887046
# ===========
#
# 72
# Title: Kitāb-al-aḍdād fi kalām al-ʻArab
# ocloc_id: 35647465
# URL: http://www.worldcat.org/oclc/35647465
# ===========
#
# 73
# Title: Perisai kebal untuk menangkis kejahatan jin dan syaitan
# ocloc_id: 850058504
# URL: http://www.worldcat.org/oclc/850058504
# ===========
#
# 74
# Title: مراتب النحويين /
# Marātib al-naḥwīyīn
# ocloc_id: 156808810
# URL: http://www.worldcat.org/oclc/156808810
# ===========
#
# 75
# Title: Na# al-lua : Inda al-insn wa al-ifl
# ocloc_id: 771077893
# URL: http://www.worldcat.org/oclc/771077893
# ===========
#
# 76
# Title: Al-Sīrah al-Nabawīyah
# ocloc_id: 25836075
# URL: http://www.worldcat.org/oclc/25836075
# ===========
#
# 77
# Title: Kitāb al-Muʻŷib fī taljīṣ ājbār al-Magrib. Lo admirable en el resumen de las noticias del Magrib,
# ocloc_id: 5746910
# URL: http://www.worldcat.org/oclc/5746910
# ===========
#
# 78
# Title: Kesalahan-kesalahan yang lazim berlaku dalam masjid
# ocloc_id: 849665966
# URL: http://www.worldcat.org/oclc/849665966
# ===========
#
# 79
# Title: Senjata tajam untuk menangkis sihir dan ilmu hitam
# ocloc_id: 850058486
# URL: http://www.worldcat.org/oclc/850058486
# ===========
#
# 80
# Title: Senjata tajam untuk menangkis sihir & ilmu hitam
# ocloc_id: 843838083
# URL: http://www.worldcat.org/oclc/843838083
# ===========
# 81
# Title: Senjata tajam untuk menangkis sihir & ilmu hitam
# ocloc_id: 843838083
# URL: http://www.worldcat.org/oclc/843838083
# ===========
#
# 82
# Title: مصادر في تاريخ المغرب والأندلس : دراسة وتحليل /
# Maṣādir fī tārīkh al-Maghrib wa-al-Andalus : dirāsah wa-taḥlīl
# ocloc_id: 739919303
# URL: http://www.worldcat.org/oclc/739919303
# ===========
#
# 83
# Title: Kerasukan jin & syaitan dan penawarnya menurut Islam
# ocloc_id: 850419812
# URL: http://www.worldcat.org/oclc/850419812
# ===========
#
# 84
# Title: Kenikmatan syurga dan kesengsaraan neraka : berdasarkan hadis-hadis sahih
# ocloc_id: 957032234
# URL: http://www.worldcat.org/oclc/957032234
# ===========
#
# 85
# Title: al-Iktifāʼ fī maġāzī Rasūl Allāh wa-ʼt̲-t̲alāt̲a al-ḫulafāʼ al-Ǧuzʼ 1 ...
# ocloc_id: 833127276
# URL: http://www.worldcat.org/oclc/833127276
# ===========
#
# 86
# Title: Perubatan Islam : menangkis kejahatan jin & sihir
# ocloc_id: 953543302
# URL: http://www.worldcat.org/oclc/953543302
# ===========
#
# 87
# Title: Merawat kemasukan jin & histeria
# ocloc_id: 850469871
# URL: http://www.worldcat.org/oclc/850469871
# ===========
#
# 88
# Title: حقوق الإنسان في الإسلام /
# Ḥuqūq al-insān fī al-Islām
# ocloc_id: 1032807535
# URL: http://www.worldcat.org/oclc/1032807535
# ===========
#
# 89
# Title: اليمن في عيون الرحالة /
# al-Yaman fī ʻuyūn al-raḥḥālah
# ocloc_id: 34379744
# URL: http://www.worldcat.org/oclc/34379744
# ===========
#
# 90
# Title: al- Kāmil fī 't-ta'rīh̲. 13
# ocloc_id: 634092214
# URL: http://www.worldcat.org/oclc/634092214
# ===========
#
# 91
# Title: al- Kāmil fī 't-ta'rīh̲. 13
# ocloc_id: 634092214
# URL: http://www.worldcat.org/oclc/634092214
# ===========
#
# 92
# Title: al- ʻAšarāt fī ġarīb al-luġa
# ocloc_id: 164876867
# URL: http://www.worldcat.org/oclc/164876867
# ===========
#
# 93
# Title: al-Iktifāʼ fī maġāzī Rasūl Allāh wa-ʼt̲-t̲alāt̲a al-ḫulafāʼ al-Ǧuzʼ 2 ...
# ocloc_id: 833127298
# URL: http://www.worldcat.org/oclc/833127298
# ===========
#
# 94
# Title: فرحات حشاد : المؤسس الشاهد، القائد الشهيد /
# Faraḥāt Ḥashshād : al-muʼassis al-shāhid, al-qāʼid al-shahīd
# ocloc_id: 893558132
# URL: http://www.worldcat.org/oclc/893558132
# ===========
#
# 95
# Title: Just an ashtray : an autobiography, the penultimate part
# ocloc_id: 1076208455
# URL: http://www.worldcat.org/oclc/1076208455
# ===========
#
# 96
# Title: Sharḥ Fatḥ al-qadīr
# ocloc_id: 26435272
# URL: http://www.worldcat.org/oclc/26435272
# ===========
#
# 97
# Title: الوفا بأحوال المصطفى /
# al-Wafā bi-aḥwāl al-Muṣṭafá
# ocloc_id: 9007172
# URL: http://www.worldcat.org/oclc/9007172
# ===========
#
# 98
# Title: الأسرة في الإسلام :عرض عام لأنظمة الأسرة في ضوء الكتاب والسنة /
# al-Usrah fī al-Islām, ʻarḍ ʻāmm li-niẓām al-usrah fī ḍawʼ al-Kitāb wa-al-sunnah
# ocloc_id: 586574606
# URL: http://www.worldcat.org/oclc/586574606
# ===========
#
# 99
# Title: الإمام أبو الحسن الأشعري (260 هـ - 324 هـ) ومؤلفاته /
# al-Imām Abū al-Ḥasan al-Ashʻarī (260 H - 324 H) wa-muʼalafātuh
# ocloc_id: 1295581878
# URL: http://www.worldcat.org/oclc/1295581878
# ===========
#
# 100
# Title: Al- Qurʼān . wa-fikrat at-tārīḫ
# ocloc_id: 313506995
# URL: http://www.worldcat.org/oclc/313506995
# ===========
#
# 101
# Title: تاريخ المغرب العربي /
# Tārīkh al-Maghrib al-ʻArabī
# ocloc_id: 59006908
# URL: http://www.worldcat.org/oclc/59006908
# ===========
#
# 102
# Title: ‏معجم المصطلحات القانونية :‏ ‏(عربي- فارسي -انكليزي) /‏
# Muʻjam al-muṣṭalaḥāt al-qānūnīyah : (ʻArabī, Faransī, Inkilīzī)
# ocloc_id: 24069167
# URL: http://www.worldcat.org/oclc/24069167
# ===========
#
# 103
# Title: تفسير كتاب ديسقوريدوس /
# Tafsīr kitāb Dīsqūrīdūs
# ocloc_id: 21585737
# URL: http://www.worldcat.org/oclc/21585737
# ===========
#
# 104
# Title: دعوة للتفكير من خلال القرآن الكريم /
# Daʻwah lil-tafkīr min khilāl al-Qurʼān al-karīm
# ocloc_id: 904763035
# URL: http://www.worldcat.org/oclc/904763035
# ===========
#
# 105
# Title: العقل المستقيل : نقد الاسلام السياسي ومرجعيته /
# al-ʻAql al-mustaqīl : naqd al-Islām al-siyāsī wa-marajaʻiyatuh
# ocloc_id: 62409948
# URL: http://www.worldcat.org/oclc/62409948
# ===========
#
# 106
# Title: تاريخ العرب وحضارتهم في الأندلس /
# Tārīkh al-ʻArab wa-ḥaḍāratuhum fī al-Andalus
# ocloc_id: 60345590
# URL: http://www.worldcat.org/oclc/60345590
# ===========
#
# 107
# Title: Al- Marʼa fi 'l-islām
# ocloc_id: 313663920
# URL: http://www.worldcat.org/oclc/313663920
# ===========
#
# 108
# Title: Maǧmūʻat al-Ḥadī_t al-Naǧdiyya
# ocloc_id: 776811157
# URL: http://www.worldcat.org/oclc/776811157
# ===========
#
# 109
# Title: Asālīb al-taʻlīm wa-maḥāratihi fī ḍawʼ al-Qurʼān al-karīm wa-al-Sunnah al-Nabawīyah al-sharīfah
# ocloc_id: 907485342
# URL: http://www.worldcat.org/oclc/907485342
# ===========
#
# 110
# Title: الترغيب في الدعاء /
# al-Targhīb fī al-du'ā'
# ocloc_id: 882493519
# URL: http://www.worldcat.org/oclc/882493519
# ===========

# %%
metadata['shelfmark'] = shelfmarks
metadata['author'] = authors
metadata['title'] = titles
metadata['query'] = query
metadata['query_results'] = query_results
metadata.to_csv('metadata.csv', index=False)
metadata_for_annotations = metadata.to_json('metadata_for_annotations.json', orient="index")

# %%
len(metadata)
# Out:
# 5

# %%
from ipywidgets import widgets

print(metadata.loc[0])




widgets.Text(value='Hello World!', disabled=True)
# Out:
# shelfmark                          14117. bbb. 24.
# author           'ABD al-RAHMAN, Hafiz, Amritsari.
# title                                KITAB AL-SARF
# query                                surname-title
# query_results                                    1
# Name: 0, dtype: object
# Text(value='Hello World!', disabled=True)

# %%
# sentence placeholder  

from ipywidgets import widgets

    
sentences = ["code1", "code2", "code3"]  
BATCH = 10
cols = ['sentence', 'label']  
df = pd.DataFrame(columns=cols, index=range(len(sentences)))  
sentence_widget = widgets.SelectMultiple(  
   options=sentences,  
   rows=BATCH,  
   description='Sentences',  
   disabled=False,  
   layout= widgets.Layout(width='50%')  
 )  
display(sentence_widget)

# class placeholder  
label = widgets.Text(description="Label", value='')  
display(label)  
# button placeholder  
button = widgets.Button(description="Annotate", disabled=False, button_style="success", tooltip="Annotate")  
output = widgets.Output()  
display(button, output)  
# progress bar placeholder  
progress = widgets.IntProgress(  
min=0,  
max=len(metadata),  
step=1,  
description='Progress:',  
orientation='horizontal',  
layout= widgets.Layout(width='20%')  
)  
display(progress)

counter = 0 #keep count of progress in dataframe  
def annotate(_):  
     
    global counter  
   
    with output:  
        label_value = label.value  
        selected_sentence = sentence_widget.value  
       
    if not len(selected_sentence):  
        print("No sentence selected!")  
        return  
    if not label_value:  
        print("No class name selected!")  
        return  
       
    progress.value += len(selected_sentence)  
   
    for i in selected_sentence:  
        df.loc[counter].sentence = i  
        df.loc[counter].label = label_value  
        counter += 1  

button.on_click(annotate)
# Out:
# SelectMultiple(description='Sentences', layout=Layout(width='50%'), options=('code1', 'code2', 'code3'), rows=…
# Text(value='', description='Label')
# Button(button_style='success', description='Annotate', style=ButtonStyle(), tooltip='Annotate')
# Output()
# IntProgress(value=0, description='Progress:', layout=Layout(width='20%'), max=5)

# %%
df
# Out:
#   sentence  label
# 0    code1     tr
# 1    code1  trtre
# 2    code1   miao

# %%
for i in range(0,len(metadata)):
    print(metadata.loc[1])
# Out:
# shelfmark                 14105. d. 106.
# author           'ABD al-SHAKUR, Maulana
# title                 KHULAFA'E RASHIDIN
# query                            surname
# query_results                         28
# Name: 1, dtype: object
# shelfmark                 14105. d. 106.
# author           'ABD al-SHAKUR, Maulana
# title                 KHULAFA'E RASHIDIN
# query                            surname
# query_results                         28
# Name: 1, dtype: object
# shelfmark                 14105. d. 106.
# author           'ABD al-SHAKUR, Maulana
# title                 KHULAFA'E RASHIDIN
# query                            surname
# query_results                         28
# Name: 1, dtype: object
# shelfmark                 14105. d. 106.
# author           'ABD al-SHAKUR, Maulana
# title                 KHULAFA'E RASHIDIN
# query                            surname
# query_results                         28
# Name: 1, dtype: object
# shelfmark                 14105. d. 106.
# author           'ABD al-SHAKUR, Maulana
# title                 KHULAFA'E RASHIDIN
# query                            surname
# query_results                         28
# Name: 1, dtype: object
