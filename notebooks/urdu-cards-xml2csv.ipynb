# %% [markdown]
# # Process Transkribus xml to Worldcat matched record

# %% [markdown]
# This notebook is part of the convert-a-card project, and was originally developed by Giorgia Tolfo, with some refactoring and extension by Harry Lloyd. The nb is designed to:
# - Parse author/title/shelfmark from Page xml data exported from automatic transcription of Urdu and Pinyin catalogue cards in Transkribus.
# - Query OCLC worldcat for matches.
# - Assign a confidence score to these matches.
# - If no match found, set up a minimal record using data extracted from the card.
# - (Possibly) allow curators to select the best matched if multiple matches are returned.

# %%
import sys
if '../' not in sys.path:
    sys.path.append('../')
import os
import glob
import re 
import xml.etree.ElementTree as ET
import pandas as pd
import requests
from z3950.PyZ3950 import zoom

# %%
ns = "{http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15}"  # xml namespace
cards = glob.glob('..\\data\\raw\\urdu_cards_pages\\page\\*.xml')  # Urdu drawer 2 from Transkribus

# %%
cards[0]
# Out:
# '..\\data\\raw\\urdu_cards_pages\\page\\0001_24567971014.xml'

# %%
def extract_labelled_xml(xml: os.PathLike, namespace):
    root = ET.parse(xml).getroot()

    text_line = f'./{namespace}TextLine/{namespace}TextEquiv/{namespace}Unicode'

    for tr in root.iter(namespace + 'TextRegion'):
        if re.search('shelfmark', tr.attrib['custom']):
            shelfmark = tr.find(text_line).text
            continue

        if re.search('title', tr.attrib['custom']):
            title = tr.find(text_line).text.replace("\"", "\'")
            continue

        if re.search('author', tr.attrib['custom']):
            author = tr.find(text_line).text.replace("\"", "\'")

    record = {'card_xml': xml, 'title': title, 'author': author, 'shelfmark': shelfmark}

    return record

# %%
records = [extract_labelled_xml(c, namespace=ns) for c in cards]
records
# Out:
# [{'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0001_24567971014.xml',
#   'title': 'KAUL-I-TAIYIB',
#   'author': 'BARNI (Muhammad Ilyas), Maulana, M.A., LL.B.',
#   'shelfmark': '14115. e. 72'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0002_24567971594.xml',
#   'title': 'AL-KAUKABAT AL-SHAHHABIYAH FI KUFARIYAT-I-ABI',
#   'author': 'BARELAWI (Muhammad Abmad Riza Khan),',
#   'shelfmark': '14105. c. 33'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0003_24567971784.xml',
#   'title': "KASRAT-I-ABKDI KA 'ILAJ",
#   'author': "SIDDIEI (Na'Im)",
#   'shelfmark': '14106. ggg. 17'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0004_24567971924.xml',
#   'title': 'KASHMIR SAZISH CASE',
#   'author': 'SRINAGAR.',
#   'shelfmark': '14119. a. 104'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0005_24567972014.xml',
#   'title': 'KASHMIR HAMARA HAI',
#   'author': 'KASHFI (Ghulam Ahmad), Mir',
#   'shelfmark': '14109. b. 101.'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0006_24567972094.xml',
#   'title': 'KASHMIR, ADAB-O-SIKAFAT',
#   'author': 'GUMMI (Salim Khan)',
#   'shelfmark': '14110. e. 28'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0007_24567972104.xml',
#   'title': "KASHIF AL-HAKA'IK",
#   'author': 'ASAR (Imdad Imam), Saiyid.',
#   'shelfmark': '14117. a. 166.'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0008_24567972144.xml',
#   'title': 'KASHF al-MAHJUB',
#   'author': 'ALI, Hujwiri, surnamed DATA GANJ BAKHSH',
#   'shelfmark': '14104. f. 103'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0009_24567972204.xml',
#   'title': "KASA'ID-I- ZAUK",
#   'author': 'MUHAMMAD IBRAHIM, called ZAUK',
#   'shelfmark': '14114. g. 87'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0010_24567972764.xml',
#   'title': 'KANTON KI SEJ',
#   'author': 'NADAWI (Rashid Akhtar)',
#   'shelfmark': '14112. b. 292.'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0011_24567972844.xml',
#   'title': 'KANDID',
#   'author': 'VOLTAIRE (Frangois Marie Aronet de)',
#   'shelfmark': '14112. a. 198'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0012_24567972884.xml',
#   'title': 'KAMYAB ZINDAGI KA TASAWWAR',
#   'author': 'DIL (Anwar), Professor.',
#   'shelfmark': '14105. d. 89.'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0013_24567973014.xml',
#   'title': 'KAMAN',
#   'author': "MALIUABADI (Na'il)",
#   'shelfmark': '14112. b. 435.'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0014_24567973344.xml',
#   'title': 'KALIM',
#   'author': 'KAISI, Rampuri.',
#   'shelfmark': '14112. b. 176'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0015_24567973364.xml',
#   'title': 'KALI TASWIR',
#   'author': 'IBN SAFI',
#   'shelfmark': '14112. b. 468.'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0016_24567973414.xml',
#   'title': 'KALI KALI TABASSUM',
#   'author': 'SHAHIN (Firozah)',
#   'shelfmark': '14112. h. 79'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0017_24567973484.xml',
#   'title': 'KALASIKI ADAB',
#   'author': 'FARUKI (Abmad), Khwajah.',
#   'shelfmark': '14117. a. 64.'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0018_24567973754.xml',
#   'title': 'KAKUL-I-SUBH',
#   'author': 'ISHRAT, Kirtpuri',
#   'shelfmark': '14114. e. 208'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0019_24567973934.xml',
#   'title': 'KAISAR-O-KISRA',
#   'author': 'NASIM, Hijazi.',
#   'shelfmark': '14112. g. 37.'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0020_24567974044.xml',
#   'title': 'KAIFIYAH',
#   'author': 'KAIFI (Brij Mohan), Datatariyah',
#   'shelfmark': '14117. ee. 8'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0021_24567997914.xml',
#   'title': 'KUCHH ZARE KUCHH TARE',
#   'author': 'MULLA (Anand Narayan)',
#   'shelfmark': '14114. 144.'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0022_24567997984.xml',
#   'title': "KUCHLI HU'I LASH",
#   'author': 'IBN SAFI',
#   'shelfmark': '14112. a. 629'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0023_24567998094.xml',
#   'title': 'KRSNACANDRA KE BIHTARIN AFSANE',
#   'author': 'KESYACANDRA',
#   'shelfmark': '14112. k. 177'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0024_24567998184.xml',
#   'title': 'KITAB AL-SARF',
#   'author': "'ABD al-RAHMAN, Hafiz, Amritsari.",
#   'shelfmark': '14117. bbb. 24.'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0025_24567998404.xml',
#   'title': 'KITAB AL-MUFRADAT',
#   'author': "A'WAN (Muzaffar Husain), Hakim.",
#   'shelfmark': '14106. g. 52'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0026_24567998524.xml',
#   'title': 'KISHAF AL-HUDA',
#   'author': "HASAN (Ya' kub)",
#   'shelfmark': '14105. f. 44.'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0027_24567998534.xml',
#   'title': 'KISHWARI',
#   'author': 'IBN HAIXT',
#   'shelfmark': '14112. a. 453'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0028_24567998604.xml',
#   'title': 'KINARA NA MILA',
#   'author': 'KAISI, Rampuri.',
#   'shelfmark': '14112. b. 136'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0029_24567998734.xml',
#   'title': 'KYA SHADI KYA GHAN',
#   'author': 'KAISI, Rampuri.',
#   'shelfmark': '14112. b. 138'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0030_24567999034.xml',
#   'title': 'KHWAB-I-JAWANI',
#   'author': 'ASLAM (M.)',
#   'shelfmark': '14112. 1. 3'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0031_24567999074.xml',
#   'title': 'KHWKB-I-HASTI',
#   'author': "ACHA HASHR, Ka'smarl.",
#   'shelfmark': '14112. bb. 64'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0032_24567999124.xml',
#   'title': 'KHUTUT-I-GHALIB',
#   'author': 'GHALIB (Asad Allah), Khan.',
#   'shelfmark': '14110. c. 53.'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0033_24567999184.xml',
#   'title': "KHUIBAT-I-KA'ID-I-A'ZAM",
#   'author': "JINNAH (Muhammad 'AlI)",
#   'shelfmark': '14119. aa. 90.'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0034_24567999574.xml',
#   'title': 'EHUNI TOLAH',
#   'author': 'NASIM, B.A.',
#   'shelfmark': '14112. h. 21'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0035_24567999824.xml',
#   'title': 'EHUN BAHTA RAHA',
#   'author': "JA'FARI (Ra is Ahmad)",
#   'shelfmark': '14112. 1. 41'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0036_24567999964.xml',
#   'title': "KHULAFA'E RASHIDIN",
#   'author': "'ABD al-SHAKUR, Maulana",
#   'shelfmark': '14105. d. 106.'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0037_24568000074.xml',
#   'title': 'KHULAFA-I-RASHIDIN',
#   'author': "'ABD al-WAHID, Dr.",
#   'shelfmark': '14109. a. 213.'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0038_24568000094.xml',
#   'title': "EHULAFA'-I-RASHIDIN",
#   'author': "ZAMKHASHARAMI (Jar Allah), 'Allamah.",
#   'shelfmark': '14105. d. 82'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0039_24568000244.xml',
#   'title': 'KHUDA NA-KH WASTA',
#   'author': 'THANAWI (Shaukat)',
#   'shelfmark': '14112. b. 146'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0040_24568000444.xml',
#   'title': 'KHUDA AUR US KE RASUL',
#   'author': "NIYKZ (Mubammad 'Abdullah), Raja.",
#   'shelfmark': '14109. a. 212.'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0041_24568000764.xml',
#   'title': 'KHETI',
#   'author': 'MUJIB (Muhammad)',
#   'shelfmark': '14112. aa. 58.'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0042_24568000864.xml',
#   'title': 'KHAWAR-NAMEH',
#   'author': 'RUSTAMI (Kamal Khan), Bijapuri',
#   'shelfmark': '14114. g. 81'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0043_24568000934.xml',
#   'title': 'KHATT-WA-KHATTATI',
#   'author': 'HUSAIN (Mumtaz), Jaunpuri and AYYUB (Muhammad),',
#   'shelfmark': '14117. b. 74.'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0044_24568001044.xml',
#   'title': 'KHAROSH-I-INTIEXN',
#   'author': 'SIDDIEI (Sadik Husain), Maulana.',
#   'shelfmark': '14112. a. 294.'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0045_24568001064.xml',
#   'title': 'KHARAM',
#   'author': 'NAKSH (Maheshoandra)',
#   'shelfmark': '14114. e. 200.'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0046_24568001094.xml',
#   'title': 'KHARABAT',
#   'author': "ADAM ('Abd al-Hamid)",
#   'shelfmark': '14114. ee. 114'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0047_24568001154.xml',
#   'title': 'KHANDAN',
#   'author': 'BAT (Raziyah)',
#   'shelfmark': '14112. h. 39'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0048_24568001254.xml',
#   'title': "EHALIFA HARUN AL-RASHID AUR US KA 'AHD",
#   'author': "JA'FARI (Ra is Ahmad)",
#   'shelfmark': '14109. bbb. 38'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0049_24568001364.xml',
#   'title': 'KHAK U KHUN',
#   'author': 'NASIM, Hijazl.',
#   'shelfmark': '14112. aa. 60'},
#  {'card_xml': '..\\data\\raw\\urdu_cards_pages\\page\\0050_24568001734.xml',
#   'title': "FUR'AN KA NAZARIYA-I-SALTANAT",
#   'author': 'SHIRWANI (Harun Khan), Professor.',
#   'shelfmark': '14105. d. 78'}]

# %%
cards_df = pd.DataFrame(records).sort_values(by=['card_xml'])
cards_df
# Out:
#                                              card_xml  \
# 0   ..\data\raw\urdu_cards_pages\page\0001_2456797...
# 1   ..\data\raw\urdu_cards_pages\page\0002_2456797...
# 2   ..\data\raw\urdu_cards_pages\page\0003_2456797...
# 3   ..\data\raw\urdu_cards_pages\page\0004_2456797...
# 4   ..\data\raw\urdu_cards_pages\page\0005_2456797...
# 5   ..\data\raw\urdu_cards_pages\page\0006_2456797...
# 6   ..\data\raw\urdu_cards_pages\page\0007_2456797...
# 7   ..\data\raw\urdu_cards_pages\page\0008_2456797...
# 8   ..\data\raw\urdu_cards_pages\page\0009_2456797...
# 9   ..\data\raw\urdu_cards_pages\page\0010_2456797...
# 10  ..\data\raw\urdu_cards_pages\page\0011_2456797...
# 11  ..\data\raw\urdu_cards_pages\page\0012_2456797...
# 12  ..\data\raw\urdu_cards_pages\page\0013_2456797...
# 13  ..\data\raw\urdu_cards_pages\page\0014_2456797...
# 14  ..\data\raw\urdu_cards_pages\page\0015_2456797...
# 15  ..\data\raw\urdu_cards_pages\page\0016_2456797...
# 16  ..\data\raw\urdu_cards_pages\page\0017_2456797...
# 17  ..\data\raw\urdu_cards_pages\page\0018_2456797...
# 18  ..\data\raw\urdu_cards_pages\page\0019_2456797...
# 19  ..\data\raw\urdu_cards_pages\page\0020_2456797...
# 20  ..\data\raw\urdu_cards_pages\page\0021_2456799...
# 21  ..\data\raw\urdu_cards_pages\page\0022_2456799...
# 22  ..\data\raw\urdu_cards_pages\page\0023_2456799...
# 23  ..\data\raw\urdu_cards_pages\page\0024_2456799...
# 24  ..\data\raw\urdu_cards_pages\page\0025_2456799...
# 25  ..\data\raw\urdu_cards_pages\page\0026_2456799...
# 26  ..\data\raw\urdu_cards_pages\page\0027_2456799...
# 27  ..\data\raw\urdu_cards_pages\page\0028_2456799...
# 28  ..\data\raw\urdu_cards_pages\page\0029_2456799...
# 29  ..\data\raw\urdu_cards_pages\page\0030_2456799...
# 30  ..\data\raw\urdu_cards_pages\page\0031_2456799...
# 31  ..\data\raw\urdu_cards_pages\page\0032_2456799...
# 32  ..\data\raw\urdu_cards_pages\page\0033_2456799...
# 33  ..\data\raw\urdu_cards_pages\page\0034_2456799...
# 34  ..\data\raw\urdu_cards_pages\page\0035_2456799...
# 35  ..\data\raw\urdu_cards_pages\page\0036_2456799...
# 36  ..\data\raw\urdu_cards_pages\page\0037_2456800...
# 37  ..\data\raw\urdu_cards_pages\page\0038_2456800...
# 38  ..\data\raw\urdu_cards_pages\page\0039_2456800...
# 39  ..\data\raw\urdu_cards_pages\page\0040_2456800...
# 40  ..\data\raw\urdu_cards_pages\page\0041_2456800...
# 41  ..\data\raw\urdu_cards_pages\page\0042_2456800...
# 42  ..\data\raw\urdu_cards_pages\page\0043_2456800...
# 43  ..\data\raw\urdu_cards_pages\page\0044_2456800...
# 44  ..\data\raw\urdu_cards_pages\page\0045_2456800...
# 45  ..\data\raw\urdu_cards_pages\page\0046_2456800...
# 46  ..\data\raw\urdu_cards_pages\page\0047_2456800...
# 47  ..\data\raw\urdu_cards_pages\page\0048_2456800...
# 48  ..\data\raw\urdu_cards_pages\page\0049_2456800...
# 49  ..\data\raw\urdu_cards_pages\page\0050_2456800...
#
#                                             title  \
# 0                                   KAUL-I-TAIYIB
# 1   AL-KAUKABAT AL-SHAHHABIYAH FI KUFARIYAT-I-ABI
# 2                         KASRAT-I-ABKDI KA 'ILAJ
# 3                             KASHMIR SAZISH CASE
# 4                              KASHMIR HAMARA HAI
# 5                         KASHMIR, ADAB-O-SIKAFAT
# 6                               KASHIF AL-HAKA'IK
# 7                                 KASHF al-MAHJUB
# 8                                 KASA'ID-I- ZAUK
# 9                                   KANTON KI SEJ
# 10                                         KANDID
# 11                     KAMYAB ZINDAGI KA TASAWWAR
# 12                                          KAMAN
# 13                                          KALIM
# 14                                    KALI TASWIR
# 15                             KALI KALI TABASSUM
# 16                                  KALASIKI ADAB
# 17                                   KAKUL-I-SUBH
# 18                                 KAISAR-O-KISRA
# 19                                       KAIFIYAH
# 20                          KUCHH ZARE KUCHH TARE
# 21                               KUCHLI HU'I LASH
# 22                 KRSNACANDRA KE BIHTARIN AFSANE
# 23                                  KITAB AL-SARF
# 24                              KITAB AL-MUFRADAT
# 25                                 KISHAF AL-HUDA
# 26                                       KISHWARI
# 27                                 KINARA NA MILA
# 28                             KYA SHADI KYA GHAN
# 29                                 KHWAB-I-JAWANI
# 30                                  KHWKB-I-HASTI
# 31                                KHUTUT-I-GHALIB
# 32                        KHUIBAT-I-KA'ID-I-A'ZAM
# 33                                    EHUNI TOLAH
# 34                                EHUN BAHTA RAHA
# 35                             KHULAFA'E RASHIDIN
# 36                             KHULAFA-I-RASHIDIN
# 37                            EHULAFA'-I-RASHIDIN
# 38                              KHUDA NA-KH WASTA
# 39                          KHUDA AUR US KE RASUL
# 40                                          KHETI
# 41                                   KHAWAR-NAMEH
# 42                              KHATT-WA-KHATTATI
# 43                              KHAROSH-I-INTIEXN
# 44                                         KHARAM
# 45                                       KHARABAT
# 46                                        KHANDAN
# 47         EHALIFA HARUN AL-RASHID AUR US KA 'AHD
# 48                                    KHAK U KHUN
# 49                  FUR'AN KA NAZARIYA-I-SALTANAT
#
#                                              author        shelfmark
# 0      BARNI (Muhammad Ilyas), Maulana, M.A., LL.B.     14115. e. 72
# 1              BARELAWI (Muhammad Abmad Riza Khan),     14105. c. 33
# 2                                   SIDDIEI (Na'Im)   14106. ggg. 17
# 3                                         SRINAGAR.    14119. a. 104
# 4                        KASHFI (Ghulam Ahmad), Mir   14109. b. 101.
# 5                                GUMMI (Salim Khan)     14110. e. 28
# 6                        ASAR (Imdad Imam), Saiyid.   14117. a. 166.
# 7           ALI, Hujwiri, surnamed DATA GANJ BAKHSH    14104. f. 103
# 8                     MUHAMMAD IBRAHIM, called ZAUK     14114. g. 87
# 9                            NADAWI (Rashid Akhtar)   14112. b. 292.
# 10              VOLTAIRE (Frangois Marie Aronet de)    14112. a. 198
# 11                          DIL (Anwar), Professor.    14105. d. 89.
# 12                               MALIUABADI (Na'il)   14112. b. 435.
# 13                                  KAISI, Rampuri.    14112. b. 176
# 14                                         IBN SAFI   14112. b. 468.
# 15                                 SHAHIN (Firozah)     14112. h. 79
# 16                         FARUKI (Abmad), Khwajah.    14117. a. 64.
# 17                                 ISHRAT, Kirtpuri    14114. e. 208
# 18                                   NASIM, Hijazi.    14112. g. 37.
# 19                  KAIFI (Brij Mohan), Datatariyah     14117. ee. 8
# 20                            MULLA (Anand Narayan)      14114. 144.
# 21                                         IBN SAFI    14112. a. 629
# 22                                      KESYACANDRA    14112. k. 177
# 23                'ABD al-RAHMAN, Hafiz, Amritsari.  14117. bbb. 24.
# 24                  A'WAN (Muzaffar Husain), Hakim.     14106. g. 52
# 25                                  HASAN (Ya' kub)    14105. f. 44.
# 26                                        IBN HAIXT    14112. a. 453
# 27                                  KAISI, Rampuri.    14112. b. 136
# 28                                  KAISI, Rampuri.    14112. b. 138
# 29                                       ASLAM (M.)      14112. 1. 3
# 30                            ACHA HASHR, Ka'smarl.    14112. bb. 64
# 31                       GHALIB (Asad Allah), Khan.    14110. c. 53.
# 32                           JINNAH (Muhammad 'AlI)   14119. aa. 90.
# 33                                      NASIM, B.A.     14112. h. 21
# 34                            JA'FARI (Ra is Ahmad)     14112. 1. 41
# 35                          'ABD al-SHAKUR, Maulana   14105. d. 106.
# 36                               'ABD al-WAHID, Dr.   14109. a. 213.
# 37             ZAMKHASHARAMI (Jar Allah), 'Allamah.     14105. d. 82
# 38                                THANAWI (Shaukat)    14112. b. 146
# 39                NIYKZ (Mubammad 'Abdullah), Raja.   14109. a. 212.
# 40                                 MUJIB (Muhammad)   14112. aa. 58.
# 41                   RUSTAMI (Kamal Khan), Bijapuri     14114. g. 81
# 42  HUSAIN (Mumtaz), Jaunpuri and AYYUB (Muhammad),    14117. b. 74.
# 43                 SIDDIEI (Sadik Husain), Maulana.   14112. a. 294.
# 44                             NAKSH (Maheshoandra)   14114. e. 200.
# 45                             ADAM ('Abd al-Hamid)   14114. ee. 114
# 46                                    BAT (Raziyah)     14112. h. 39
# 47                            JA'FARI (Ra is Ahmad)   14109. bbb. 38
# 48                                   NASIM, Hijazl.    14112. aa. 60
# 49                SHIRWANI (Harun Khan), Professor.     14105. d. 78

# %%
# df.to_csv('test_with_lxml_new.csv')

# %%
# can use print(r) to visually print out a whole MARC record retrieved from worldcat

def OCLC_query(title="", author=""):
    # TODO Connection currently only handles 450 results at once before closing, extend or allow to reopen after 450
    conn = zoom.Connection(
        host='zcat.oclc.org',
        port=210,
        user='100270667',
        password='oclccat',
        databaseName='OLUCWorldCat',
        preferredRecordSyntax='USMARC'
    )
    q = f'ti="{title}" and au="{author}"'
    print(q)
    query = zoom.Query(q)
    res = conn.search(query)

    if res:
        res_dict = {i: r for i, r in enumerate(res)}
        conn.close()
        return res_dict
    else:
        conn.close()
        return None

# %%
normal_people = OCLC_query(author='Sally Rooney')

# %%
normal_people[0]

# %%
# This query returns > 450 results which at the moment is more than one zoom connection allows
# OCLC_query("Madame Bovary", 'Flaubert')

# %%
cards_df.head()
# Out:
#                                             card_xml  \
# 0  ..\data\raw\urdu_cards_pages\page\0001_2456797...
# 1  ..\data\raw\urdu_cards_pages\page\0002_2456797...
# 2  ..\data\raw\urdu_cards_pages\page\0003_2456797...
# 3  ..\data\raw\urdu_cards_pages\page\0004_2456797...
# 4  ..\data\raw\urdu_cards_pages\page\0005_2456797...
#
#                                            title  \
# 0                                  KAUL-I-TAIYIB
# 1  AL-KAUKABAT AL-SHAHHABIYAH FI KUFARIYAT-I-ABI
# 2                        KASRAT-I-ABKDI KA 'ILAJ
# 3                            KASHMIR SAZISH CASE
# 4                             KASHMIR HAMARA HAI
#
#                                          author       shelfmark
# 0  BARNI (Muhammad Ilyas), Maulana, M.A., LL.B.    14115. e. 72
# 1          BARELAWI (Muhammad Abmad Riza Khan),    14105. c. 33
# 2                               SIDDIEI (Na'Im)  14106. ggg. 17
# 3                                     SRINAGAR.   14119. a. 104
# 4                    KASHFI (Ghulam Ahmad), Mir  14109. b. 101.

# %%
OCLC_query(cards_df.loc[32,'title'], cards_df.loc[32,'author'])
# Out:
# ti="KHUIBAT-I-KA'ID-I-A'ZAM" and au="JINNAH (Muhammad 'AlI)"

# %%
res = cards_df.apply(lambda x: OCLC_query(x['title'], x['author']),axis=1)
cards_df['worldcat_result'] = res
# Out:
# ti="KAUL-I-TAIYIB" and au="BARNI (Muhammad Ilyas), Maulana, M.A., LL.B."
# ti="AL-KAUKABAT AL-SHAHHABIYAH FI KUFARIYAT-I-ABI" and au="BARELAWI (Muhammad Abmad Riza Khan),"
# ti="KASRAT-I-ABKDI KA 'ILAJ" and au="SIDDIEI (Na'Im)"
# ti="KASHMIR SAZISH CASE" and au="SRINAGAR."
# ti="KASHMIR HAMARA HAI" and au="KASHFI (Ghulam Ahmad), Mir"
# ti="KASHMIR, ADAB-O-SIKAFAT" and au="GUMMI (Salim Khan)"
# ti="KASHIF AL-HAKA'IK" and au="ASAR (Imdad Imam), Saiyid."
# ti="KASHF al-MAHJUB" and au="ALI, Hujwiri, surnamed DATA GANJ BAKHSH"
# ti="KASA'ID-I- ZAUK" and au="MUHAMMAD IBRAHIM, called ZAUK"
# ti="KANTON KI SEJ" and au="NADAWI (Rashid Akhtar)"
# ti="KANDID" and au="VOLTAIRE (Frangois Marie Aronet de)"
# ti="KAMYAB ZINDAGI KA TASAWWAR" and au="DIL (Anwar), Professor."
# ti="KAMAN" and au="MALIUABADI (Na'il)"
# ti="KALIM" and au="KAISI, Rampuri."
# ti="KALI TASWIR" and au="IBN SAFI"
# ti="KALI KALI TABASSUM" and au="SHAHIN (Firozah)"
# Extracting 2 starting at 0
# ti="KALASIKI ADAB" and au="FARUKI (Abmad), Khwajah."
# ti="KAKUL-I-SUBH" and au="ISHRAT, Kirtpuri"
# ti="KAISAR-O-KISRA" and au="NASIM, Hijazi."
# ti="KAIFIYAH" and au="KAIFI (Brij Mohan), Datatariyah"
# ti="KUCHH ZARE KUCHH TARE" and au="MULLA (Anand Narayan)"
# ti="KUCHLI HU'I LASH" and au="IBN SAFI"
# Extracting 1 starting at 0
# ti="KRSNACANDRA KE BIHTARIN AFSANE" and au="KESYACANDRA"
# ti="KITAB AL-SARF" and au="'ABD al-RAHMAN, Hafiz, Amritsari."
# ti="KITAB AL-MUFRADAT" and au="A'WAN (Muzaffar Husain), Hakim."
# ti="KISHAF AL-HUDA" and au="HASAN (Ya' kub)"
# ti="KISHWARI" and au="IBN HAIXT"
# ti="KINARA NA MILA" and au="KAISI, Rampuri."
# ti="KYA SHADI KYA GHAN" and au="KAISI, Rampuri."
# ti="KHWAB-I-JAWANI" and au="ASLAM (M.)"
# ti="KHWKB-I-HASTI" and au="ACHA HASHR, Ka'smarl."
# ti="KHUTUT-I-GHALIB" and au="GHALIB (Asad Allah), Khan."
# Extracting 2 starting at 0
# ti="KHUIBAT-I-KA'ID-I-A'ZAM" and au="JINNAH (Muhammad 'AlI)"
# ti="EHUNI TOLAH" and au="NASIM, B.A."
# ti="EHUN BAHTA RAHA" and au="JA'FARI (Ra is Ahmad)"
# ti="KHULAFA'E RASHIDIN" and au="'ABD al-SHAKUR, Maulana"
# ti="KHULAFA-I-RASHIDIN" and au="'ABD al-WAHID, Dr."
# ti="EHULAFA'-I-RASHIDIN" and au="ZAMKHASHARAMI (Jar Allah), 'Allamah."
# ti="KHUDA NA-KH WASTA" and au="THANAWI (Shaukat)"
# ti="KHUDA AUR US KE RASUL" and au="NIYKZ (Mubammad 'Abdullah), Raja."
# ti="KHETI" and au="MUJIB (Muhammad)"
# Extracting 4 starting at 0
# ti="KHAWAR-NAMEH" and au="RUSTAMI (Kamal Khan), Bijapuri"
# ti="KHATT-WA-KHATTATI" and au="HUSAIN (Mumtaz), Jaunpuri and AYYUB (Muhammad),"
# ti="KHAROSH-I-INTIEXN" and au="SIDDIEI (Sadik Husain), Maulana."
# ti="KHARAM" and au="NAKSH (Maheshoandra)"
# ti="KHARABAT" and au="ADAM ('Abd al-Hamid)"
# ti="KHANDAN" and au="BAT (Raziyah)"
# Extracting 5 starting at 0
# ti="EHALIFA HARUN AL-RASHID AUR US KA 'AHD" and au="JA'FARI (Ra is Ahmad)"
# ti="KHAK U KHUN" and au="NASIM, Hijazl."
# ti="FUR'AN KA NAZARIYA-I-SALTANAT" and au="SHIRWANI (Harun Khan), Professor."

# %%
cards_df.loc[10]
# Out:
# card_xml           ..\data\raw\urdu_cards_pages\page\0011_2456797...
# title                                                         KANDID
# author                           VOLTAIRE (Frangois Marie Aronet de)
# shelfmark                                              14112. a. 198
# worldcat_result                                                 None
# Name: 10, dtype: object

# %%
cards_df.dropna()
# Out:
#                                              card_xml               title  \
# 15  ..\data\raw\urdu_cards_pages\page\0016_2456797...  KALI KALI TABASSUM
# 21  ..\data\raw\urdu_cards_pages\page\0022_2456799...    KUCHLI HU'I LASH
# 31  ..\data\raw\urdu_cards_pages\page\0032_2456799...     KHUTUT-I-GHALIB
# 40  ..\data\raw\urdu_cards_pages\page\0041_2456800...               KHETI
# 46  ..\data\raw\urdu_cards_pages\page\0047_2456800...             KHANDAN
#
#                         author       shelfmark  \
# 15            SHAHIN (Firozah)    14112. h. 79
# 21                    IBN SAFI   14112. a. 629
# 31  GHALIB (Asad Allah), Khan.   14110. c. 53.
# 40            MUJIB (Muhammad)  14112. aa. 58.
# 46               BAT (Raziyah)    14112. h. 39
#
#                                       worldcat_result
# 15  {0: =LDR  00890cam  2200253   4500
# =001  ocm46...
# 21  {0: =LDR  01410cam  2200421Ma 4500
# =001  ocn81...
# 31  {0: =LDR  00719cam  2200241Ma 4500
# =001  ocn65...
# 40  {0: =LDR  01342cam  22003377a 4500
# =001  ocm46...
# 46  {0: =LDR  00871cam  2200301 a 4500
# =001  ocm20...

# %%
cards_df.loc[46]
# Out:
# card_xml           ..\data\raw\urdu_cards_pages\page\0047_2456800...
# title                                                        KHANDAN
# author                                                 BAT (Raziyah)
# shelfmark                                               14112. h. 39
# worldcat_result    {0: =LDR  00871cam  2200301 a 4500
# =001  ocm20...
# Name: 46, dtype: object

# %%
print(cards_df.loc[46, "worldcat_result"][0])
# Out:
# =LDR  00871cam  2200301 a 4500
# =001  ocm20990610#
# =003  OCoLC
# =005  20230509081726.0
# =008  900202s1971####pk############000#1#urd#d
# =010  ## $a   72930428
# =029  1# $aAU@$b000028373298
# =035  ## $a(OCoLC)20990610
# =040  ## $aKQM$beng$cKQM$dCGU$dCUY$dOCLCQ$dOCLCF$dOCLCQ$dOCLCO$dOCLCQ
# =050  04 $aPK2200.R4$bK53
# =082  04 $a891.4393$bRAZ, Urdu
# =100  0# $aRaz̤iyah Baṭ.
# =245  10 $aK̲h̲āndān.
# =260  ## $aLāhaur :$bĪsṭarn Pablisharz,$c[1971]
# =300  ## $a400 pages ;$c18 cm
# =336  ## $atext$btxt$2rdacontent
# =337  ## $aunmediated$bn$2rdamedia
# =338  ## $avolume$bnc$2rdacarrier
# =500  ## $aA novel.
# =546  ## $aIn Urdu.
# =650  #0 $aUrdu fiction.
# =650  #7 $aUrdu fiction.$2fast$0(OCoLC)fst01162764
# =948  ## $hNO HOLDINGS IN BLX - 13 OTHER HOLDINGS
# =994  ## $aZ0$bBLX

# %%
print(cards_df.loc[46, "worldcat_result"][1])
# Out:
# =LDR  01035cam  2200313 a 4500
# =001  ocm45943867#
# =003  OCoLC
# =005  20230509081726.0
# =008  010215s1999####ii############000#f#urdod
# =035  ## $a(OCoLC)45943867
# =040  ## $aIGA$beng$cIGA$dZQP$dOCLCQ$dOJ4$dOCLCF$dGK8$dOCLCO$dOCLCA$dOCLCQ
# =066  ## $c(3$c(4
# =082  04 $aFic$bRAZIYAH BAT
# =100  0# $6880-01$aRaẓiyah Baṭ.
# =245  10 $6880-02$aK̲h̲āndān /$cRaz̤iyah Baṭ.
# =260  ## $6880-03$aNaʼī Dihlī :$bAhlūvāliyah Bukḍipo,$c1999.
# =300  ## $a336 pages ;$c19 cm
# =336  ## $atext$btxt$2rdacontent
# =337  ## $aunmediated$bn$2rdamedia
# =338  ## $avolume$bnc$2rdacarrier
# =500  ## $aNovel.
# =546  ## $aIn Urdu.
# =650  #0 $aUrdu fiction.
# =650  #7 $aUrdu fiction.$2fast$0(OCoLC)fst01162764
# =880  0# $6100-01/(3/r$a(3QVjg HJ.(B
# =880  10 $6245-02/(3/r$a(3NGfOGf /(B$c(3QVjg HJ.(B
# =880  ## $6260-03/(3/r$a(3fFi Ogdi :(B$b(3GgdhhGdjg HcO(4)(3h,(B,$c1999.
# =948  ## $hNO HOLDINGS IN BLX - 6 OTHER HOLDINGS
# =994  ## $aZ0$bBLX

# %%
print(cards_df.loc[46, "worldcat_result"][4])
# Out:
# =LDR  00699cam  2200253M  4500
# =001  ocn976620288
# =003  OCoLC
# =005  20230509081726.0
# =008  740710s1971####pk############000#0#urd#d
# =019  ## $a225397538
# =035  ## $a(OCoLC)976620288$z(OCoLC)225397538
# =040  ## $aCNUTO$beng$cCNUTO$dOCLCQ
# =050  #4 $aPK2200 R383$bK4
# =050  #4 $aPK2200 .R383K4$bROBA
# =082  04 $a891.4393$qOCoLC
# =100  1# $aRaz̤iyah Baṭ
# =245  10 $aKhāndān.
# =260  ## $aLahore$bEastern Publishers$c[1971]
# =300  ## $a400 pages
# =336  ## $atext$btxt$2rdacontent
# =337  ## $aunmediated$bn$2rdamedia
# =338  ## $avolume$bnc$2rdacarrier
# =948  ## $hNO HOLDINGS IN BLX - 2 OTHER HOLDINGS
# =994  ## $aZ0$bBLX

# %%
'''This includes a very cut-down version of https://github.com/asl2/PyZ3950 and some code for parsing MARC records which is loosely based on https://pypi.org/project/pymarc/
 
Hopefully you will be able to run the two example queries in the file test_queries.py and work from there. Both of the queries use authentication credentials – you should probably check whether LibCrowds has ever had its own credentials, especially for querying OCLC as I think we do get charged something annuals for permission to derive records from them.
 
My cut-down version of the scripts will only do z3950 searches (no other kinds of transactions, e.g. sorting, writing, deleting), and only uses CCL query language. See https://help.oclc.org/Resource_Sharing/Relais_ILL/DiscoverItem/DiscoverItem_Search/020Constructing_CCL_query for information on CCL queries, and note that there are other query languages with the same initials! There is probably still a lot of redundant code and dead ends in there – I haven’t had time yet to work out what everything does.'''

# %%
# %%capture cap --no-stderr
# print 'stuff'
# with open('output.txt', 'w') as f:
#     f.write(cap.stdout)

# %%
#testing

# %%
# tree = ET.parse('./urdu_cards_pages/1032971/U2_for_Transkribus/page/0001_24567971014.xml')
# root = tree.getroot()
    
# shelfmarks = []
# titles = []
# authors = []
# record = []

# for TextRegion in root.iter(ns+'TextRegion'):
#     if re.search('shelfmark', TextRegion.attrib['custom']):
#         y = TextRegion.find('./{http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15}TextLine/{http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15}TextEquiv/{http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15}Unicode')
#         print(y.text)

# %%
root.find('.//{'+ns+'}TextLine/')

# %%
tree = ET.parse('./urdu_cards_pages/1032971/U2_for_Transkribus/page/0001_24567971014.xml')
root = tree.getroot()

shelfmarks = []
titles = []
authors = []
record = []

for TextRegion in root.iter(ns+'TextRegion'):
        if re.search('shelfmark', TextRegion.attrib['custom']) :
            el_shelfmark = TextRegion.find('./{http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15}TextLine/{http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15}TextEquiv/{http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15}Unicode') 
            if el_shelfmark is not None:
                shelfmarks.append(el_shelfmark.text)
                
            else:
                shelfmark = None
        
        else:
            shelfmark = None
      


        if re.search('title', TextRegion.attrib['custom']):
            el_title = TextRegion.find('./{http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15}TextLine/{http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15}TextEquiv/{http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15}Unicode')
            
            if el_title is not None:
                titles.append(el_title.text)
                
            else:
                title = None
           
            
        else:
            title = None
            



        if re.search('author', TextRegion.attrib['custom']):
            el_author = TextRegion.find('./{http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15}TextLine/{http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15}TextEquiv/{http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15}Unicode')
            if el_author is not None:
                authors.append(el_author.text)
                
            else:
                author = None
        
        
        else:
            author = None

print('Shelfmark: ', shelfmarks)
print('Title: ', titles)
print('Author: ', authors)
